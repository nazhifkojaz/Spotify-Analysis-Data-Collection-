# %% [markdown]
# # Library Imports

# %%
import pandas as pd
import glob
import requests
import time

# %% [markdown]
# # Data Imports / Exports

# %%
# THESE FILES ARE EXCLUDED FROM THE REPOSITORY
stream_json = glob.glob('datasets/Streaming_History_Audio*.json')

# %%
# see the list of globbed files
stream_json
# Out:
# ['datasets\\Streaming_History_Audio_2016-2017_0.json',
#  'datasets\\Streaming_History_Audio_2017-2018_1.json',
#  'datasets\\Streaming_History_Audio_2018-2019_2.json',
#  'datasets\\Streaming_History_Audio_2019-2020_3.json',
#  'datasets\\Streaming_History_Audio_2020-2021_4.json',
#  'datasets\\Streaming_History_Audio_2021-2022_5.json',
#  'datasets\\Streaming_History_Audio_2022-2023_6.json',
#  'datasets\\Streaming_History_Audio_2023_7.json',
#  'datasets\\Streaming_History_Audio_2023_8.json']

# %%
# load the globbed files into a dataframe
stream_df = pd.concat([pd.read_json(f) for f in stream_json])

# %%
tracks_df = pd.read_csv('datasets/tracks_df.csv')
podcasts_df = pd.read_csv('datasets/podcasts_df.csv')
# Out:
# C:\Users\Kim\AppData\Local\Temp\ipykernel_14320\2056156176.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   tracks_df = pd.read_csv('datasets/tracks_df.csv')

# %%
print(stream_df.shape)
print(stream_df.columns)
# Out:
# (128775, 21)
# Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
stream_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128775 entries, 0 to 1545
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 128775 non-null  object
#  1   username                           128775 non-null  object
#  2   platform                           128775 non-null  object
#  3   ms_played                          128775 non-null  int64
#  4   conn_country                       128775 non-null  object
#  5   ip_addr_decrypted                  108167 non-null  object
#  6   user_agent_decrypted               108167 non-null  object
#  7   master_metadata_track_name         127961 non-null  object
#  8   master_metadata_album_artist_name  127961 non-null  object
#  9   master_metadata_album_album_name   127961 non-null  object
#  10  spotify_track_uri                  127961 non-null  object
#  11  episode_name                       639 non-null     object
#  12  episode_show_name                  639 non-null     object
#  13  spotify_episode_uri                639 non-null     object
#  14  reason_start                       128775 non-null  object
#  15  reason_end                         108167 non-null  object
#  16  shuffle                            128775 non-null  bool
#  17  skipped                            22580 non-null   object
#  18  offline                            128775 non-null  bool
#  19  offline_timestamp                  128775 non-null  int64
#  20  incognito_mode                     128775 non-null  bool
# dtypes: bool(3), int64(2), object(16)
# memory usage: 19.0+ MB

# %%
# number of unique values in each column
stream_df.nunique()
# Out:
# ts                                   121283
# username                                  1
# platform                                 33
# ms_played                             26836
# conn_country                              9
# ip_addr_decrypted                      2737
# user_agent_decrypted                      6
# master_metadata_track_name             4714
# master_metadata_album_artist_name      1639
# master_metadata_album_album_name       2680
# spotify_track_uri                      5172
# episode_name                            295
# episode_show_name                        31
# spotify_episode_uri                     295
# reason_start                              8
# reason_end                               10
# shuffle                                   2
# skipped                                   2
# offline                                   2
# offline_timestamp                    126902
# incognito_mode                            2
# dtype: int64

# %%
stream_df.isna().sum()
# Out:
# ts                                        0
# username                                  0
# platform                                  0
# ms_played                                 0
# conn_country                              0
# ip_addr_decrypted                     20608
# user_agent_decrypted                  20608
# master_metadata_track_name              814
# master_metadata_album_artist_name       814
# master_metadata_album_album_name        814
# spotify_track_uri                       814
# episode_name                         128136
# episode_show_name                    128136
# spotify_episode_uri                  128136
# reason_start                              0
# reason_end                            20608
# shuffle                                   0
# skipped                              106195
# offline                                   0
# offline_timestamp                         0
# incognito_mode                            0
# dtype: int64

# %%
stream_df['user_agent_decrypted'].value_counts()
# Out:
# user_agent_decrypted
# unknown                                                                                                                                                                  108091
# Mozilla%2F5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit%2F537.36%20(KHTML,%20like%20Gecko)%20Chrome%2F95.0.4638.54%20Safari%2F537.36%20Edg%2F95.0.1020.40        66
# Mozilla%2F5.0%20(Windows%20NT%2010.0;%20Win64;%20x64;%20rv:84.0)%20Gecko%2F20100101%20Firefox%2F84.0                                                                          6
# Mozilla%2F5.0%20(Windows%20NT%2010.0;%20Win64;%20x64;%20rv:61.0)%20Gecko%2F20100101%20Firefox%2F61.0                                                                          2
# Mozilla%2F5.0%20(Windows%20NT%2010.0;%20Win64;%20x64;%20rv:69.0)%20Gecko%2F20100101%20Firefox%2F69.0                                                                          1
# Mozilla%2F5.0%20(Windows%20NT%2010.0;%20Win64;%20x64;%20rv:83.0)%20Gecko%2F20100101%20Firefox%2F83.0                                                                          1
# Name: count, dtype: int64

# %%
# dropping some columns that might cnotain sensitive information or just not useful
stream_df.drop(columns=['username', 'ip_addr_decrypted', 'user_agent_decrypted'], inplace=True)

# %% [markdown]
# there are a huge number of null value of 'spotify_episode_uri', indicating that tracks/songs and podcasts don't share same uri, we need to separate this into its own dataframe (for tracks and podcasts)

# %% [markdown]
# # Preparing for Data Collection
# we need 4 things here.
# 1. tracks streaming history
# 2. podcasts streaming history
# 3. list of unique tracks streamed
# 4. ~~list of unique podcasts streamed~~ not really needed actually

# %%
# rows with null in both spotify_track_uri and spotify_episode_uri
print(stream_df[stream_df['spotify_episode_uri'].isna() & stream_df['spotify_track_uri'].isna()].shape)
print(stream_df[stream_df['spotify_episode_uri'].notna() & stream_df['spotify_track_uri'].notna()].shape)
# Out:
# (175, 18)
# (0, 18)

# %% [markdown]
# so apparently there exists some rows are null on both spotify_episode_uri and spotify_track_uri, so those should be excluded as well

# %%
# get rows with null values in 'spotify_episode_uri' column and put it into a new dataframe
tracks_df = stream_df[stream_df['spotify_track_uri'].notna()]
podcasts_df = stream_df[stream_df['spotify_episode_uri'].notna()]

# %%
print(tracks_df.shape)
print(podcasts_df.shape)
# Out:
# (127961, 18)
# (639, 18)

# %%
# list of tracks, containing unique values in 'spotify_track_uri' column
tracks_uri_list = tracks_df['spotify_track_uri'].unique().tolist()
podcasts_uri_list = podcasts_df['spotify_episode_uri'].unique().tolist()

# %%
print(len(tracks_uri_list))
print(len(podcasts_uri_list))
# Out:
# 5172
# 295

# %%
# save tracks_df and podcasts_df into csv
tracks_df.to_csv('datasets/tracks_df.csv', index=False)
podcasts_df.to_csv('datasets/podcasts_df.csv', index=False)

# %% [markdown]
# # Data Collection (Spotipy)
# now we're going to collect the using [Spotipy](https://spotipy.readthedocs.io/en/2.22.1/), it'll require user credentials (client_id and client_secret) which you can get [here](https://developer.spotify.com/dashboard) by registering your app at the dashboard

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Spotify API credentials (client_id and client_secret used will be excluded from the repository)
client_id = 'YOUR CLIENT ID HERE'
client_secret = 'YOUR CLIENT SECRET HERE'

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## get track info

# %%
# since they have the batch request limit of 50, we need to split the list into batches of 50
track_info = {}
for i in range(0, len(tracks_uri_list), 50):
    track_batch = tracks_uri_list[i:i+50]
    sapi = sp.tracks(track_batch)
    for track in sapi['tracks']:
        track_info[track['id']] = {'name':track['name'], 'artistName':track['artists'][0]['name'], 'release_date':track['album']['release_date'], 'popularity':track['popularity'], 'duration_ms':track['duration_ms']}
    time.sleep(1)

# %%
len(track_info)
# Out:
# 5172

# %%
track_info
# Out:
# {'6tAM5c0bJOwRqGAEgiNMpI': {'name': 'Solace Album Mix',
#   'artistName': 'Monstercat',
#   'release_date': '2012-06-06',
#   'popularity': 0,
#   'duration_ms': 3538579},
#  '4mjgNE8R31AzxWfPNGtVMf': {'name': 'Best of 2015 (Album Mix)',
#   'artistName': 'Monstercat',
#   'release_date': '2016-01-22',
#   'popularity': 0,
#   'duration_ms': 9158194},
#  '5Q0P0cX3e42PgKd8LLS3ms': {'name': 'Horizon Album Mix',
#   'artistName': 'Monstercat',
#   'release_date': '2014-08-06',
#   'popularity': 0,
#   'duration_ms': 3623121},
#  '6jvMmRtSzoEibQGrQkSISQ': {'name': 'Monstercat Best of 2012',
#   'artistName': 'Monstercat',
#   'release_date': '2013-02-04',
#   'popularity': 0,
#   'duration_ms': 6348017},
#  '1KzLyjpjIRHuuj4iX8QsC2': {'name': 'Monstercat Podcast EP. 100',
#   'artistName': 'Monstercat',
#   'release_date': '2016-04-05',
#   'popularity': 0,
#   'duration_ms': 9744610},
#  '4VrdksXJVhAOLW49qV0VTQ': {'name': 'Best of 2014 (Album Mix - Part 1)',
#   'artistName': 'Monstercat',
#   'release_date': '2015-01-26',
#   'popularity': 0,
#   'duration_ms': 3374468},
#  '0ng42pTjKgskmobNzhnEUa': {'name': 'Monstercat Podcast EP. 101 (Hush Takeover)',
#   'artistName': 'Monstercat',
#   'release_date': '2016-04-12',
#   'popularity': 0,
#   'duration_ms': 3701042},
#  '1ip1SN4tWX0qMgE1KgIF52': {'name': 'Calling Out (feat. KG & Skyelle)',
#   'artistName': 'MUZZ',
#   'release_date': '2015-12-18',
#   'popularity': 0,
#   'duration_ms': 335923},
#  '05LCfd8s9n2teUcsTsBAnr': {'name': 'Alladat',
#   'artistName': 'Jarren Benton',
#   'release_date': '2015-01-27',
#   'popularity': 13,
#   'duration_ms': 207560},
#  '1uy20tUwglZ4hapeq50jSL': {'name': 'Saving My Love - Stfu Mix',
#   'artistName': 'Twin Pack',
#   'release_date': '2011-11-25',
#   'popularity': 0,
#   'duration_ms': 386718},
#  '0EEWFu8Becr1CKzCljRiEG': {'name': 'オトノナルホウヘ→',
#   'artistName': 'Goose house',
#   'release_date': '2015-04-06',
#   'popularity': 0,
#   'duration_ms': 216173},
#  '2nYxM6Di7mhBTv26K887fQ': {'name': 'Sky',
#   'artistName': 'Goose house',
#   'release_date': '2011-11-25',
#   'popularity': 14,
#   'duration_ms': 334081},
#  '4kFW3sV8K3YRYG04Qhxdjw': {'name': 'バーチャル#9',
#   'artistName': 'Goose house',
#   'release_date': '2011-08-20',
#   'popularity': 15,
#   'duration_ms': 286668},
#  '6mPGkCjfAZ1PR52RBxXumL': {'name': '”JUST FRIENDS”?',
#   'artistName': 'Goose house',
#   'release_date': '2011-08-20',
#   'popularity': 13,
#   'duration_ms': 299259},
#  '167PWPhEUGgTXuRkRCCCSD': {'name': 'Fly High, So High',
#   'artistName': 'Goose house',
#   'release_date': '2016-09-16',
#   'popularity': 0,
#   'duration_ms': 283706},
#  '3AyQKxtCEk3ZR3JRnEpuSe': {'name': 'Best Friend',
#   'artistName': 'Goose house',
#   'release_date': '2016-09-16',
#   'popularity': 0,
#   'duration_ms': 286306},
#  '7piGheKcgabl2VgB1YkVEo': {'name': 'Perfume',
#   'artistName': 'Goose house',
#   'release_date': '2015-04-06',
#   'popularity': 0,
#   'duration_ms': 223840},
#  '54PTOiC3MbDJGt9zpf6Jac': {'name': '恋するMerry-Go-Round',
#   'artistName': 'Goose house',
#   'release_date': '2015-04-06',
#   'popularity': 0,
#   'duration_ms': 277026},
#  '3IG6jyqLWwEyvPaGwEepcr': {'name': 'Pop Up!',
#   'artistName': 'Goose house',
#   'release_date': '2015-04-06',
#   'popularity': 0,
#   'duration_ms': 231546},
#  '3nKu0IIjJLU4h1cM5eTBiQ': {'name': '笑ったままで',
#   'artistName': 'Goose house',
#   'release_date': '2015-04-06',
#   'popularity': 0,
#   'duration_ms': 255800},
#  '2kBR8dkyKfd25W9PRUFrLh': {'name': "Don't Get It Misunderstood (feat. Venice)",
#   'artistName': 'Kyle Coglitore',
#   'release_date': '2015-10-28',
#   'popularity': 19,
#   'duration_ms': 139702},
#  '0skMV1gLpuvWFx1oKVBEkv': {'name': 'Up In Flumes',
#   'artistName': 'T-Mass',
#   'release_date': '2014-12-27',
#   'popularity': 0,
#   'duration_ms': 212165},
#  '1WSH5C56sRGwgbpH4cndH0': {'name': 'Paper Planes',
#   'artistName': 'Virtual Riot',
#   'release_date': '2014-04-06',
#   'popularity': 0,
#   'duration_ms': 228870},
#  '19aFbIM6m8suZZnP0YDhW2': {'name': 'Let It Go',
#   'artistName': 'Gene Galuska',
#   'release_date': '2014-06-10',
#   'popularity': 0,
#   'duration_ms': 247480},
#  '4mKaGkUNWrbDtvTl7sZDkt': {'name': "Can't Forget You (ft. The Nicholas)",
#   'artistName': 'San Holo',
#   'release_date': '2015-11-20',
#   'popularity': 0,
#   'duration_ms': 216363},
#  '0IavpjES4TgnNw2RPYDDey': {'name': "Can't Forget",
#   'artistName': 'Omar LinX',
#   'release_date': '2014-03-17',
#   'popularity': 39,
#   'duration_ms': 217093},
#  '15O20RQyWJgKrkHID9ynT9': {'name': 'Never Be Like You',
#   'artistName': 'Flume',
#   'release_date': '2016-05-27',
#   'popularity': 0,
#   'duration_ms': 233337},
#  '48qF1yaxtfOga12D6xR0Im': {'name': 'Alone (Slushii Remix)',
#   'artistName': 'Marshmello',
#   'release_date': '2016-08-25',
#   'popularity': 0,
#   'duration_ms': 259212},
#  '2bfGNzdiRa1jXZRdfssSzR': {'name': 'Dirty Harry',
#   'artistName': 'Gorillaz',
#   'release_date': '2005-05-23',
#   'popularity': 72,
#   'duration_ms': 230426},
#  '26ZC396ABpfS0MIbOetGEV': {'name': 'Summer Never Ends',
#   'artistName': 'Anna Yvette',
#   'release_date': '2016-07-25',
#   'popularity': 0,
#   'duration_ms': 231225},
#  '2QzQU3nEL5kcCI11o5AfmK': {'name': 'Yours Truly (feat. Danyka Nadeau)',
#   'artistName': 'Mr FijiWiji',
#   'release_date': '2015-02-13',
#   'popularity': 0,
#   'duration_ms': 282026},
#  '1Kny6fGX5BzfhI3emVgMVz': {'name': 'Into the Limelight (feat. Danyka Nadeau)',
#   'artistName': 'Trivecta',
#   'release_date': '2016-06-03',
#   'popularity': 0,
#   'duration_ms': 270000},
#  '1Y4z9pcqHF9KHHnZQoB07O': {'name': 'Mandala',
#   'artistName': '5054281243927',
#   'release_date': '2019-01-25',
#   'popularity': 0,
#   'duration_ms': 237215},
#  '6rn7zSeV46JMH0hJa4JJ6O': {'name': 'Time Stops',
#   'artistName': 'Virtual Riot',
#   'release_date': '2015-09-21',
#   'popularity': 0,
#   'duration_ms': 276374},
#  '4AP0fHeJ9MRGiS1i1xlw7Y': {'name': 'Real Love (feat. Danyka Nadeau)',
#   'artistName': 'Rootkit',
#   'release_date': '2014-06-30',
#   'popularity': 0,
#   'duration_ms': 275409},
#  '46zeAK3nRlfjRmHf22lpQc': {'name': 'Dangerous (feat. Danyka Nadeau)',
#   'artistName': 'Televisor',
#   'release_date': '2015-12-18',
#   'popularity': 0,
#   'duration_ms': 268004},
#  '1x59YtDtw7jPZTxqNYmhq2': {'name': 'Crossroad (feat. Danyka Nadeau)',
#   'artistName': 'Au5',
#   'release_date': '2014-12-14',
#   'popularity': 0,
#   'duration_ms': 417314},
#  '12mGwph2YzDIlChtq3EdXP': {'name': 'Alone',
#   'artistName': 'Marshmello',
#   'release_date': '2016-05-13',
#   'popularity': 1,
#   'duration_ms': 273802},
#  '7IPCUIHT37O1mbk4R9O6En': {'name': 'Unbreakable (feat. Danyka Nadeau)',
#   'artistName': 'Hyper Potions',
#   'release_date': '2016-04-25',
#   'popularity': 0,
#   'duration_ms': 264954},
#  '51O58Axxs6CFiJzf1uUflq': {'name': 'Breathe (feat. Danyka Nadeau)',
#   'artistName': 'Tut Tut Child',
#   'release_date': '2014-10-31',
#   'popularity': 0,
#   'duration_ms': 275121},
#  '204PudWeSLHxVwOkune8mr': {'name': 'Inside (feat. Danyka Nadeau)',
#   'artistName': 'Au5',
#   'release_date': '2015-08-17',
#   'popularity': 0,
#   'duration_ms': 289970},
#  '7BKLCZ1jbUBVqRi2FVlTVw': {'name': 'Closer',
#   'artistName': 'The Chainsmokers',
#   'release_date': '2016-07-29',
#   'popularity': 86,
#   'duration_ms': 244960},
#  '0UZwcRQAk4QR09HtGRZhYC': {'name': 'Closer To The Edge',
#   'artistName': 'Thirty Seconds To Mars',
#   'release_date': '2009-01-01',
#   'popularity': 63,
#   'duration_ms': 273466},
#  '5HOpkTTVcmZHnthgyxrIL8': {'name': 'The Fox (What Does the Fox Say?)',
#   'artistName': 'Ylvis',
#   'release_date': '2013-09-02',
#   'popularity': 66,
#   'duration_ms': 213708},
#  '59PCsXjyZnAzDTOyC4QdZx': {'name': 'Stonehenge',
#   'artistName': 'Ylvis',
#   'release_date': '2011-10-31',
#   'popularity': 0,
#   'duration_ms': 233560},
#  '6tO70xUCWTTjH73QHMAvb9': {'name': 'The Cabin',
#   'artistName': 'Ylvis',
#   'release_date': '2013-10-26',
#   'popularity': 0,
#   'duration_ms': 248158},
#  '4KX39APEOO2EgiZFkcJOfR': {'name': 'Together',
#   'artistName': 'Martin Garrix',
#   'release_date': '2016-10-20',
#   'popularity': 48,
#   'duration_ms': 221274},
#  '5MFzQMkrl1FOOng9tq6R9r': {'name': "Don't Wanna Know",
#   'artistName': 'Maroon 5',
#   'release_date': '2016-10-11',
#   'popularity': 0,
#   'duration_ms': 214480},
#  '5Fm1OwRebHb5GFwdT3ia89': {'name': 'Mercy',
#   'artistName': 'Shawn Mendes',
#   'release_date': '2016-09-23',
#   'popularity': 0,
#   'duration_ms': 208733},
#  '1oR7VE2YJv3kT5XIa0MGMS': {'name': 'Sing',
#   'artistName': 'Goose house',
#   'release_date': '2011-08-20',
#   'popularity': 36,
#   'duration_ms': 260441},
#  '0urpBLpcm6DOGzs86rcKd8': {'name': 'Untuk Perempuan Yang Sedang Di Pelukan',
#   'artistName': 'Payung Teduh',
#   'release_date': '2014-11-04',
#   'popularity': 75,
#   'duration_ms': 342000},
#  '4NrgHwCBgIQfst4NT2CmM3': {'name': 'Cerita Tentang Gunung Dan Laut',
#   'artistName': 'Payung Teduh',
#   'release_date': '2010-12-16',
#   'popularity': 44,
#   'duration_ms': 425626},
#  '11m2Qis3Q4uX3pBKjYefAc': {'name': 'Kucari Kamu',
#   'artistName': 'Payung Teduh',
#   'release_date': '2010-12-16',
#   'popularity': 58,
#   'duration_ms': 277666},
#  '7wIkCYvFL159wjEDRn4qWI': {'name': "Why Can't We Be Friends?",
#   'artistName': 'War',
#   'release_date': '1975',
#   'popularity': 0,
#   'duration_ms': 230066},
#  '4yNoaxUJjnP50AXYoAZx4S': {'name': 'Emotional',
#   'artistName': 'Flux Pavilion',
#   'release_date': '2015-09-18',
#   'popularity': 50,
#   'duration_ms': 235275},
#  '271feX4Fipo7wGlxTYqjQa': {'name': 'First Love (feat. Diamond Eyes)',
#   'artistName': 'Curious Kontrol',
#   'release_date': '2014-01-21',
#   'popularity': 0,
#   'duration_ms': 255312},
#  '5Dk2YjSwm9U2WC1nsFuwrD': {'name': 'Bring the Madness (Noisestorm Remix) [feat. Mayor Apeshit]',
#   'artistName': 'Excision',
#   'release_date': '2015-03-23',
#   'popularity': 0,
#   'duration_ms': 240000},
#  '44lyaXavLM0ulSopAS1F1J': {'name': 'Showtime',
#   'artistName': 'Shazzka',
#   'release_date': '2015-09-04',
#   'popularity': 14,
#   'duration_ms': 251682},
#  '7i0Pa4mJTJVIMw7Vy3FFUi': {'name': 'Find the Light (feat. Harley Holmes)',
#   'artistName': 'audalanche',
#   'release_date': '2016-02-15',
#   'popularity': 0,
#   'duration_ms': 183774},
#  '4jyPwgbt41phI3JionKQR8': {'name': 'Chasing (feat. Phoebe Ryan) - Giuliano Rascan Remix',
#   'artistName': 'Mt. Eden',
#   'release_date': '2014-01-14',
#   'popularity': 5,
#   'duration_ms': 232960},
#  '5ck7Ye06LHgGhWYJiAps2Q': {'name': 'Annunaki',
#   'artistName': 'Extra Terra',
#   'release_date': '2015-07-17',
#   'popularity': 15,
#   'duration_ms': 241507},
#  '0ng4EHlOtKCQfpJjH5djmB': {'name': 'Mix This Feeling - Original Mix',
#   'artistName': 'Centron',
#   'release_date': '2014-10-06',
#   'popularity': 0,
#   'duration_ms': 246953},
#  '6l8YTdyBFxP4m7fGNaUl58': {'name': 'Pieces',
#   'artistName': 'CHIMES',
#   'release_date': '2015-07-01',
#   'popularity': 0,
#   'duration_ms': 273750},
#  '6lHjGJAIrTWVqWn1NAiYlG': {'name': 'ShadowBoxz',
#   'artistName': 'D1ofAquavibe',
#   'release_date': '2015-09-10',
#   'popularity': 6,
#   'duration_ms': 222595},
#  '5bX55UxmDPHnNDnee3Nhkx': {'name': 'Break Away',
#   'artistName': 'Foria',
#   'release_date': '2016-01-14',
#   'popularity': 0,
#   'duration_ms': 301714},
#  '6cxzIx8KTDEhCfGH9TAcDT': {'name': "You've Got to Move",
#   'artistName': 'Disfigure',
#   'release_date': '2013-01-12',
#   'popularity': 7,
#   'duration_ms': 248952},
#  '6KzHQR35nTZ336ABF9IiuQ': {'name': 'Los Angeles',
#   'artistName': 'Vaski',
#   'release_date': '2016-01-31',
#   'popularity': 0,
#   'duration_ms': 192500},
#  '52oaUia8TvAcPvAeLL1M5F': {'name': 'Possessed - M4SONIC Remix',
#   'artistName': 'TGC',
#   'release_date': '2015-01-17',
#   'popularity': 10,
#   'duration_ms': 261541},
#  '2TNmy12Kv86t5Wt0LMDfIT': {'name': 'Surreal (Feat. Abby Sevcik)',
#   'artistName': 'Mielo',
#   'release_date': '2017-10-20',
#   'popularity': 0,
#   'duration_ms': 228031},
#  '34dkIFtyGlcg4qN0X9NBO3': {'name': 'Lack Of Shame - Original Mix',
#   'artistName': 'Elènne',
#   'release_date': '2014-01-24',
#   'popularity': 4,
#   'duration_ms': 291166},
#  '3s4gfqgL8GW4sKD6HCbTCO': {'name': 'Best in the West',
#   'artistName': 'Lets Be Friends',
#   'release_date': '2013-07-08',
#   'popularity': 33,
#   'duration_ms': 298626},
#  '4mdKjIVwZn8r0CdxfdeLRg': {'name': 'Release',
#   'artistName': 'JayKode',
#   'release_date': '2015-07-06',
#   'popularity': 0,
#   'duration_ms': 246073},
#  '57JB8Nk90z6NHT9OCB5RTi': {'name': 'Kaede - Original Mix',
#   'artistName': 'Nhato',
#   'release_date': '2015-12-21',
#   'popularity': 13,
#   'duration_ms': 408311},
#  '6CLuXOJNHuLVAbhUP5XWFM': {'name': 'Faces',
#   'artistName': 'L Plus',
#   'release_date': '2013-02-03',
#   'popularity': 0,
#   'duration_ms': 314493},
#  '5Bi7zxA9t47MkTzMr5rYvZ': {'name': 'Arigato!',
#   'artistName': 'W-Fu !!!',
#   'release_date': '2016-05-10',
#   'popularity': 12,
#   'duration_ms': 320177},
#  '3GUCa7VYKUcwTr5VWIkXg9': {'name': 'Killing Giants (EFL103)',
#   'artistName': 'Puppet & Murtagh',
#   'release_date': '2016-11-15',
#   'popularity': 13,
#   'duration_ms': 274427},
#  '12f77tAz7FPaFxnFABoZbH': {'name': 'Complete - R.O Remix',
#   'artistName': 'LigOne',
#   'release_date': '2015-01-21',
#   'popularity': 12,
#   'duration_ms': 199500},
#  '5fSS1HoqUnDitEc7IYSBTd': {'name': 'True Stories',
#   'artistName': 'Axero',
#   'release_date': '2015-09-24',
#   'popularity': 25,
#   'duration_ms': 274838},
#  '718lC48FqA6liN6xSgBUhm': {'name': 'Robot Love',
#   'artistName': 'Klaypex',
#   'release_date': '2015-04-28',
#   'popularity': 36,
#   'duration_ms': 231640},
#  '6YjA9S9LK1hrUFdbwz453x': {'name': 'Beyond the Void',
#   'artistName': 'Arkana',
#   'release_date': '2014-12-18',
#   'popularity': 0,
#   'duration_ms': 321904},
#  '4XFMaZTEmNvsmKeQUxCfQ4': {'name': 'Knife (Tofû Remix)',
#   'artistName': 'Nola Wren',
#   'release_date': '2016-11-18',
#   'popularity': 16,
#   'duration_ms': 205090},
#  '0nX4hydaOORRDqlfZfJA07': {'name': 'Running Away',
#   'artistName': 'Ollygon',
#   'release_date': '2014-12-22',
#   'popularity': 5,
#   'duration_ms': 257560},
#  '5IJbTPhcj0IjdzUaYqwe2I': {'name': 'Stfu',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 55,
#   'duration_ms': 224493},
#  '3JaKlOxGyK5S38uI2YabYn': {'name': 'Why You Always Lying?',
#   'artistName': 'Nicholas Fraser',
#   'release_date': '2016-01-12',
#   'popularity': 40,
#   'duration_ms': 227106},
#  '4l1NjfkuYjoSbYjrMB6z2T': {'name': 'Lights',
#   'artistName': 'DJ Striden',
#   'release_date': '2015-10-01',
#   'popularity': 30,
#   'duration_ms': 195437},
#  '5fA5LqjhNlAk3iwwSldHAy': {'name': 'Obama Mic Drop (1999)',
#   'artistName': 'The Gregory Brothers',
#   'release_date': '2016-01-14',
#   'popularity': 28,
#   'duration_ms': 144246},
#  '6fkjRwfYTWdzjW6HzWIlPX': {'name': 'Titenic',
#   'artistName': 'Jon Tron',
#   'release_date': '2015-06-09',
#   'popularity': 36,
#   'duration_ms': 180647},
#  '3WyawnjePexe2eqMKauJBR': {'name': 'Popcorn',
#   'artistName': 'Joey Rumble',
#   'release_date': '2016-07-18',
#   'popularity': 0,
#   'duration_ms': 221648},
#  '5zOz2xrNP1x6Znpe9PaDCd': {'name': 'Cure',
#   'artistName': 'Cole Sipe',
#   'release_date': '2015-09-10',
#   'popularity': 0,
#   'duration_ms': 217411},
#  '71SZ2WDbxKnDEq1vVVj2Je': {'name': 'Closer Further',
#   'artistName': 'Toxic Emotion',
#   'release_date': '2016-09-16',
#   'popularity': 0,
#   'duration_ms': 209240},
#  '0SxZpiF1BfbLiKJAamelYz': {'name': "I'm Beginning To Think You Prefer Beverly Hills 90210 To Me",
#   'artistName': 'Fight Like Apes',
#   'release_date': '2009-01-26',
#   'popularity': 0,
#   'duration_ms': 203413},
#  '6kQ9Os7x5LJ2jLHb8VWKaa': {'name': 'ninelie',
#   'artistName': 'Aimer',
#   'release_date': '2016',
#   'popularity': 0,
#   'duration_ms': 261773},
#  '3oshLPqyQEEWBCktWl8jfS': {'name': 'Another Earth',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 31,
#   'duration_ms': 132206},
#  '01LSU6meTykNfXu66aBTvZ': {'name': 'Small Dick',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 35,
#   'duration_ms': 132285},
#  '7rE9wYXPgLqZsXVxn2JhU9': {'name': 'Pink Life',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 40,
#   'duration_ms': 190640},
#  '7qiZfU4dY1lWllzX7mPBI3': {'name': 'Shape of You',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 89,
#   'duration_ms': 233712},
#  '0afhq8XCExXpqazXczTSve': {'name': 'Galway Girl',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 81,
#   'duration_ms': 170826},
#  '3eR23VReFzcdmS7TYCrhCe': {'name': "It Ain't Me (with Selena Gomez)",
#   'artistName': 'Kygo',
#   'release_date': '2017-02-16',
#   'popularity': 80,
#   'duration_ms': 220780},
#  '0PyWKgNmGiYTFe6MXN5U4K': {'name': 'Bounce Back',
#   'artistName': 'Big Sean',
#   'release_date': '2017-02-03',
#   'popularity': 0,
#   'duration_ms': 222360},
#  '2pJZ1v8HezrAoZ0Fhzby92': {'name': 'What Do I Know?',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 69,
#   'duration_ms': 237333},
#  '6syOdAs4IK8kPWR7gDyjRw': {'name': 'Congratulations',
#   'artistName': 'Post Malone',
#   'release_date': '2016-12-09',
#   'popularity': 0,
#   'duration_ms': 220293},
#  '0KKkJNfGyhkQ5aFogxQAPU': {'name': "That's What I Like",
#   'artistName': 'Bruno Mars',
#   'release_date': '2016-11-17',
#   'popularity': 89,
#   'duration_ms': 206693},
#  '1yNyoWWWikbLhwIGWjZuDW': {'name': 'All Night',
#   'artistName': 'The Vamps',
#   'release_date': '2016-10-14',
#   'popularity': 0,
#   'duration_ms': 197793},
#  '14uKsvPJ0quzQvdB6f7Dur': {'name': 'Call on Me (Ryan Riback Remix)',
#   'artistName': 'Starley',
#   'release_date': '2016-09-23',
#   'popularity': 65,
#   'duration_ms': 222040},
#  '2EEeOnHehOozLq4aS0n6SL': {'name': 'iSpy (feat. Lil Yachty)',
#   'artistName': 'KYLE',
#   'release_date': '2016-12-02',
#   'popularity': 73,
#   'duration_ms': 253106},
#  '5aAx2yezTd8zXrkmtKl66Z': {'name': 'Starboy',
#   'artistName': 'The Weeknd',
#   'release_date': '2016-11-25',
#   'popularity': 36,
#   'duration_ms': 230453},
#  '15vzANxN8G9wWfwAJLLMCg': {'name': 'Paris',
#   'artistName': 'The Chainsmokers',
#   'release_date': '2017-01-13',
#   'popularity': 70,
#   'duration_ms': 221520},
#  '3Lfiu5sZ4M4B6JaKMBc0FU': {'name': 'Barcelona',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 66,
#   'duration_ms': 191146},
#  '5uCax9HTNlzGybIStD3vDh': {'name': "Say You Won't Let Go",
#   'artistName': 'James Arthur',
#   'release_date': '2016-10-28',
#   'popularity': 88,
#   'duration_ms': 211466},
#  '1CnPYaKxTVb4LWOtiGOm0m': {'name': 'All Time Low',
#   'artistName': 'Jon Bellion',
#   'release_date': '2016-06-10',
#   'popularity': 69,
#   'duration_ms': 217603},
#  '51ChrwmUPDJvedPQnIU8Ls': {'name': 'Dive',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 75,
#   'duration_ms': 238440},
#  '3rOSwuTsUlJp0Pu0MkN8r8': {'name': 'Mask Off',
#   'artistName': 'Future',
#   'release_date': '2017-08-04',
#   'popularity': 50,
#   'duration_ms': 204600},
#  '3TJk0aoXM0knrOlgd1fnbx': {'name': 'Weak',
#   'artistName': 'AJR',
#   'release_date': '2017',
#   'popularity': 0,
#   'duration_ms': 202186},
#  '35QZaWQRkmnAVqBF1TLCxQ': {'name': 'Nancy Mulligan',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 67,
#   'duration_ms': 179786},
#  '6PCUP3dWmTjcTtXY02oFdT': {'name': 'Castle on the Hill',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 82,
#   'duration_ms': 261153},
#  '7oolFzHipTMg2nL7shhdz2': {'name': 'Eraser',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 60,
#   'duration_ms': 227426},
#  '1dNIEtp7AY3oDAKCGg2XkH': {'name': 'Something Just Like This',
#   'artistName': 'The Chainsmokers',
#   'release_date': '2017-02-22',
#   'popularity': 75,
#   'duration_ms': 247626},
#  '3ebXMykcMXOcLeJ9xZ17XH': {'name': 'Scared to Be Lonely',
#   'artistName': 'Martin Garrix',
#   'release_date': '2017-01-27',
#   'popularity': 80,
#   'duration_ms': 220883},
#  '5knuzwU65gJK7IF5yJsuaW': {'name': 'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'artistName': 'Clean Bandit',
#   'release_date': '2016-10-21',
#   'popularity': 77,
#   'duration_ms': 251088},
#  '6PJ8FF6UR8FZXfEvpHkIVN': {'name': 'How Would You Feel (Paean)',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 67,
#   'duration_ms': 280533},
#  '6gpcs5eMhJwax4mIfKDYQk': {'name': 'Slide (feat. Frank Ocean & Migos)',
#   'artistName': 'Calvin Harris',
#   'release_date': '2017-02-24',
#   'popularity': 72,
#   'duration_ms': 230813},
#  '5ndfVSDyPq90jaIUhNPeby': {'name': 'Chained To The Rhythm',
#   'artistName': 'Katy Perry',
#   'release_date': '2017-02-10',
#   'popularity': 0,
#   'duration_ms': 237915},
#  '2SZy40PLDk3vFucXUGFCFA': {'name': "You Don't Know Me",
#   'artistName': 'Jax Jones',
#   'release_date': '2016-12-09',
#   'popularity': 0,
#   'duration_ms': 213946},
#  '6VRghJeP6I0w1KxkdWFfIh': {'name': 'Believer',
#   'artistName': 'Imagine Dragons',
#   'release_date': '2017-01-31',
#   'popularity': 0,
#   'duration_ms': 203782},
#  '5HDPtsnyb3maFmPL8LLUTG': {'name': 'New Man',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 65,
#   'duration_ms': 189280},
#  '0dA2Mk56wEzDgegdC6R17g': {'name': 'Stay (with Alessia Cara)',
#   'artistName': 'Zedd',
#   'release_date': '2017-02-23',
#   'popularity': 1,
#   'duration_ms': 210090},
#  '4RepvCWqsP6zBuzvwYibAS': {'name': 'I Feel It Coming',
#   'artistName': 'The Weeknd',
#   'release_date': '2016-11-25',
#   'popularity': 0,
#   'duration_ms': 269186},
#  '0tgVpDi06FyKpA1z0VMD4v': {'name': 'Perfect',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 90,
#   'duration_ms': 263400},
#  '2dfHh7ECGxfNqZTQno09Vk': {'name': "Hearts Don't Break Around Here",
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 64,
#   'duration_ms': 248413},
#  '3WOUyEmV9Hi12JKn9QeLjI': {'name': 'Everybody (feat. Phillip Müller)',
#   'artistName': 'K-391',
#   'release_date': '2014-12-04',
#   'popularity': 0,
#   'duration_ms': 311259},
#  '2RttW7RAu5nOAfq6YFvApB': {'name': 'Happier',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 80,
#   'duration_ms': 207520},
#  '5Wh7OXtD7BzzUmhwzOpBZb': {'name': 'Run Up (feat. PARTYNEXTDOOR & Nicki Minaj)',
#   'artistName': 'Major Lazer',
#   'release_date': '2017-01-26',
#   'popularity': 37,
#   'duration_ms': 203180},
#  '6HUnnBwYZqcED1eQztxMBN': {'name': 'Solo Dance',
#   'artistName': 'Martin Jensen',
#   'release_date': '2016-11-04',
#   'popularity': 1,
#   'duration_ms': 174933},
#  '1sXUWdKx03aP9Gmzft58rt': {'name': 'Issues',
#   'artistName': 'Julia Michaels',
#   'release_date': '2017-01-13',
#   'popularity': 1,
#   'duration_ms': 176346},
#  '4Km5HrUvYTaSUfiSGPJeQR': {'name': 'Bad and Boujee (feat. Lil Uzi Vert)',
#   'artistName': 'Migos',
#   'release_date': '2017-04-07',
#   'popularity': 8,
#   'duration_ms': 343150},
#  '1WniHvhq9zTkny0WvGXX8o': {'name': 'Chantaje',
#   'artistName': 'Shakira',
#   'release_date': '2016',
#   'popularity': 0,
#   'duration_ms': 195612},
#  '5NNlUMcOEOdoOIwwaWXv0k': {'name': 'Cold',
#   'artistName': 'Maroon 5',
#   'release_date': '2017-02-14',
#   'popularity': 0,
#   'duration_ms': 234308},
#  '1WC5UN1U79gJlxGLYDGIO7': {'name': 'Green Light',
#   'artistName': 'Lorde',
#   'release_date': '2017-03-02',
#   'popularity': 0,
#   'duration_ms': 234661},
#  '3EmmCZoqpWOTY1g2GBwJoR': {'name': 'Just Hold On',
#   'artistName': 'Steve Aoki',
#   'release_date': '2016-12-10',
#   'popularity': 62,
#   'duration_ms': 198774},
#  '7nKBxz47S9SD79N086fuhn': {'name': 'SUBEME LA RADIO',
#   'artistName': 'Enrique Iglesias',
#   'release_date': '2017-02-24',
#   'popularity': 71,
#   'duration_ms': 207680},
#  '4VuS959DSpr82t3qBqCrWG': {'name': 'Supermarket Flowers',
#   'artistName': 'Ed Sheeran',
#   'release_date': '2017-03-03',
#   'popularity': 77,
#   'duration_ms': 221106},
#  '3umS4y3uQDkqekNjVpiRUs': {'name': 'El Amante',
#   'artistName': 'Nicky Jam',
#   'release_date': '2017-01-20',
#   'popularity': 70,
#   'duration_ms': 219506},
#  '4aWmUDTfIPGksMNLV2rQP2': {'name': 'Despacito (Featuring Daddy Yankee)',
#   'artistName': 'Luis Fonsi',
#   'release_date': '2017-01-13',
#   'popularity': 0,
#   'duration_ms': 228200},
#  '5yzuAVmDCCuRM5bDT9H4Y0': {'name': 'I Have a Gun',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 37,
#   'duration_ms': 110000},
#  '5rRMux9vrgG0HAnW8AgFCt': {'name': 'Nickelodeon Girls',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 47,
#   'duration_ms': 188546},
#  '3NdDpSvN911VPGivFlV5d0': {'name': 'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#   'artistName': 'ZAYN',
#   'release_date': '2016-12-09',
#   'popularity': 0,
#   'duration_ms': 245200},
#  '043MJ8zk9VQLvXXV01UbH6': {'name': 'Fairy Tail Theme',
#   'artistName': 'Taylor Davis',
#   'release_date': '2012-12-15',
#   'popularity': 44,
#   'duration_ms': 188000},
#  '37Yr8hkrWzfWT7ZRsfCOzX': {'name': 'Attack on Titan Theme (Guren No Yumiya)',
#   'artistName': 'Taylor Davis',
#   'release_date': '2014-07-29',
#   'popularity': 33,
#   'duration_ms': 171986},
#  '527iyT77FKfKsWb59QeetM': {'name': 'Fairy Tail Theme',
#   'artistName': 'Taylor Davis',
#   'release_date': '2014-07-29',
#   'popularity': 38,
#   'duration_ms': 208933},
#  '6BwGADsK48truigixSvLps': {'name': 'He\'s a Pirate (From "Pirates of the Caribbean")',
#   'artistName': 'Taylor Davis',
#   'release_date': '2013-07-23',
#   'popularity': 42,
#   'duration_ms': 157640},
#  '3UCrsQ2v8vexY7pcsoUxo1': {'name': "Assassin's Creed III Theme",
#   'artistName': 'Taylor Davis',
#   'release_date': '2012-12-15',
#   'popularity': 29,
#   'duration_ms': 174222},
#  '0fDXx9vVgfdLZasmDoVnqP': {'name': 'The Avengers Theme',
#   'artistName': 'Taylor Davis',
#   'release_date': '2013-08-27',
#   'popularity': 0,
#   'duration_ms': 124000},
#  '4KbrSpUpAViTkxs7e4aunN': {'name': 'Game of Thrones Theme',
#   'artistName': 'Taylor Davis',
#   'release_date': '2013-03-26',
#   'popularity': 31,
#   'duration_ms': 201847},
#  '4Wqyc4zng66azPNuGp9Hp7': {'name': 'Arrival to Earth (Transformers)',
#   'artistName': 'Taylor Davis',
#   'release_date': '2012-06-28',
#   'popularity': 17,
#   'duration_ms': 246000},
#  '1IbqahgWSIgMcgUxbupT19': {'name': 'Swordland (From "Sword Art Online")',
#   'artistName': 'Taylor Davis',
#   'release_date': '2015-09-01',
#   'popularity': 28,
#   'duration_ms': 178124},
#  '7HHIwfRPcfnvUTK2zOGrD0': {'name': 'RE:I AM',
#   'artistName': 'Aimer',
#   'release_date': '2014-06-25',
#   'popularity': 0,
#   'duration_ms': 345133},
#  '2PH4A0uzqE8DSinxxETZrE': {'name': 'Cold Sun',
#   'artistName': 'Aimer',
#   'release_date': '2014-06-25',
#   'popularity': 0,
#   'duration_ms': 309093},
#  '6HH1qlyyVAAJzbctS0OYKB': {'name': 'No.1',
#   'artistName': 'Kana Nishino',
#   'release_date': '2010',
#   'popularity': 0,
#   'duration_ms': 252000},
#  '2fcg8FwEs3OhcyT91mbvT4': {'name': 'トリセツ',
#   'artistName': 'Kana Nishino',
#   'release_date': '2016-07-15',
#   'popularity': 0,
#   'duration_ms': 257253},
#  '2NMBRQiJSTuiLBCwHVTlnq': {'name': 'スピカ',
#   'artistName': 'Aimer',
#   'release_date': '2016-05-11',
#   'popularity': 0,
#   'duration_ms': 308413},
#  '4XD7dBLAbo3C5UF8N5WuD1': {'name': 'Best Friend',
#   'artistName': 'Kana Nishino',
#   'release_date': '2013-09-04',
#   'popularity': 0,
#   'duration_ms': 319840},
#  '0f34MnV51uwA1jhPQ2XnDe': {'name': 'Brave Shine',
#   'artistName': 'Aimer',
#   'release_date': '2015-07-29',
#   'popularity': 0,
#   'duration_ms': 233493},
#  '2p7kd9XmOXxSd9Czqdl59B': {'name': '眠りの森',
#   'artistName': 'Aimer',
#   'release_date': '2014-06-25',
#   'popularity': 0,
#   'duration_ms': 273360},
#  '7nMyG8CJCgLweioZNOqRJc': {'name': 'Through My Blood <AM>',
#   'artistName': 'Aimer',
#   'release_date': '2016-05-11',
#   'popularity': 0,
#   'duration_ms': 241533},
#  '1JdnhcPSrGF8bGzUdXw96l': {'name': 'Distance',
#   'artistName': 'Kana Nishino',
#   'release_date': '2013-09-04',
#   'popularity': 0,
#   'duration_ms': 226600},
#  '7hDc8b7IXETo14hHIHdnhd': {'name': 'Passionfruit',
#   'artistName': 'Drake',
#   'release_date': '2017-03-18',
#   'popularity': 0,
#   'duration_ms': 298940},
#  '3GnLo84IkdSWCPYt6tnLll': {'name': 'HUMBLE.',
#   'artistName': 'Kendrick Lamar',
#   'release_date': '2017-03-31',
#   'popularity': 1,
#   'duration_ms': 177604},
#  '1x5sYLZiu9r5E43kMlt9f8': {'name': 'Symphony (feat. Zara Larsson)',
#   'artistName': 'Clean Bandit',
#   'release_date': '2017-03-16',
#   'popularity': 76,
#   'duration_ms': 212459},
#  '6Zosz8w6CmdGMZM6p4JlbQ': {'name': 'Me Rehúso',
#   'artistName': 'Danny Ocean',
#   'release_date': '2016-09-16',
#   'popularity': 0,
#   'duration_ms': 205741},
#  '2BoS7pU92MQtynhQ0cZOLT': {'name': 'Tunnel Vision',
#   'artistName': 'Kodak Black',
#   'release_date': '2017-02-17',
#   'popularity': 50,
#   'duration_ms': 268186},
#  '2jG6ifTWXk0AvonlgcXGgZ': {'name': 'Portland',
#   'artistName': 'Drake',
#   'release_date': '2017-03-18',
#   'popularity': 2,
#   'duration_ms': 236614},
#  '5hYTyyh2odQKphUbMqc5gN': {'name': 'How Far I\'ll Go - From "Moana"',
#   'artistName': 'Alessia Cara',
#   'release_date': '2016-10-28',
#   'popularity': 0,
#   'duration_ms': 175517},
#  '37Hr7Cnjt9uqPpPqDnjsWo': {'name': "Why Can't We Be Friends?",
#   'artistName': 'War',
#   'release_date': '1994-10-18',
#   'popularity': 23,
#   'duration_ms': 228333},
#  '3SP0MlWYfu7xt1ZfMqBxh9': {'name': 'FEAR.',
#   'artistName': 'Kendrick Lamar',
#   'release_date': '2017-04-14',
#   'popularity': 0,
#   'duration_ms': 460573},
#  '5ELRkzdzz0HvGpMDlfZHkV': {'name': 'Sign of the Times',
#   'artistName': 'Harry Styles',
#   'release_date': '2017-04-07',
#   'popularity': 1,
#   'duration_ms': 340706},
#  '2j3g68OQNQKEmQW7kDJeKO': {'name': "Goofy's Trial",
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 36,
#   'duration_ms': 166402},
#  '7zvKFw17XyoBUx9mHiwzPy': {'name': 'Rice Balls',
#   'artistName': 'Pink Guy',
#   'release_date': '2017-01-04',
#   'popularity': 45,
#   'duration_ms': 196173},
#  '6x959m2QDvatSwUAVCHIuf': {'name': "Why Can't We Be Friends",
#   'artistName': 'War',
#   'release_date': '1975-01-01',
#   'popularity': 61,
#   'duration_ms': 230106},
#  '5VnaOLeK1lKfULuNwet8ck': {'name': 'Flowers',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017-10-23',
#   'popularity': 60,
#   'duration_ms': 252121},
#  '6vKK2Gy6QSCjt8nMVdMXX5': {'name': 'Everybody Dances Except Me',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 29,
#   'duration_ms': 91200},
#  '2XizvxDAomTbA3KOnOgGcc': {'name': "Let's Walk Across This Forest, I Can Feel Everything Being Real Again",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 43,
#   'duration_ms': 139807},
#  '47p7dDK9JvK3O0STbQL02u': {'name': 'I Think We Should Break Up',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 25,
#   'duration_ms': 111157},
#  '3nhBvq3wC6zsNf23cYvXFT': {'name': "We'll Be Together",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 27,
#   'duration_ms': 234666},
#  '654qURfLGShCjqo8VvHQ47': {'name': 'Lapis',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 33,
#   'duration_ms': 56528},
#  '6Z7RZRCnM3oLktccT2Bgbm': {'name': 'Thoughts',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 40,
#   'duration_ms': 132075},
#  '0GbSslWDNItJQPA788gr20': {'name': 'Healing',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 38,
#   'duration_ms': 247484},
#  '5cvbog6wen3r3bBbcwL16U': {'name': "We've Never Met but Can We Have a Cup of Coffee or Something",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017-10-23',
#   'popularity': 55,
#   'duration_ms': 199603},
#  '6NxTzPkAVrLOZXh6KV6x8T': {'name': "When You Think About Her and Your Brain Says No Don't Do That",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 34,
#   'duration_ms': 166400},
#  '3HO8tYJGwNdOlctYzGhzkH': {'name': 'Good Morning Qt',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 28,
#   'duration_ms': 78720},
#  '51NwEhU00taacC9npdji7W': {'name': 'I Just Loved You (feat. Tomppabeats & Oiseaubizarre)',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 38,
#   'duration_ms': 114000},
#  '3lXP9X4TWjSHzpVKv6t4A7': {'name': "Goodbye Earth I'm Taking My Spaceship to Explore the Universe",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 30,
#   'duration_ms': 119172},
#  '7fB9Qu6IcMRhAg1L7SB0ir': {'name': 'Ghost',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2013',
#   'popularity': 0,
#   'duration_ms': 172800},
#  '2Csg0XMPdNmHLozWODtsQq': {'name': "I Was Feeling Down, I Found a Nice Witch and We're Friends",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 47,
#   'duration_ms': 230243},
#  '23VciRIsKDL6JjfhQzTKiY': {'name': 'I Thought We Were Lovers (feat. Basil)',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 37,
#   'duration_ms': 157518},
#  '7q4Z1OieVSNeplX7Rgw5u0': {'name': 'I Need a Cup of Coffee and Some Bread to Wake Up',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 51,
#   'duration_ms': 60000},
#  '3dkLN75ITjlF3TK1D4M1bw': {'name': "Welcome At Qwerty and Azerty's Place",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 30,
#   'duration_ms': 35631},
#  '1xxlEIFljtiUYVXufYup84': {'name': 'Can I Be Your Internet Crush',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 27,
#   'duration_ms': 205090},
#  '600wewdSes7BMxXmm6UD7M': {'name': "I Don't Know and I Don't Want to Know",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 25,
#   'duration_ms': 186000},
#  '29cp4vju8mOmmPYBwsPtLb': {'name': 'You and Me - Dancing',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2013',
#   'popularity': 0,
#   'duration_ms': 216409},
#  '1g89nNWU8XIjUQwc8BNVTD': {'name': 'Am I a Girl? Am I a Boy? Do I Really Care?',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 48,
#   'duration_ms': 59480},
#  '75imPZaXVxdqNVnRV44KsK': {'name': "Qwerty Enchanted The House and Now It's Attacking Us",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 35,
#   'duration_ms': 88685},
#  '7xRfZ4bQgEg60LQa3vgx02': {'name': "I Know It's Not Easy but You're Not Alone Anymore",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 40,
#   'duration_ms': 142759},
#  '3PqWJMsNn4yh9lFqBbYhuE': {'name': "Sorry for Not Answering the Phone I'm Too Busy Trying to Fly Away",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017-10-23',
#   'popularity': 48,
#   'duration_ms': 132413},
#  '6Lr6YaV8KW41iD53PgjPr5': {'name': "Chilling At Nemu's Place",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 48,
#   'duration_ms': 46315},
#  '3ij9PeVmzqcsztIgi6fWok': {'name': 'Comet',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 28,
#   'duration_ms': 138556},
#  '5gNx7WNPQG7gEMfRAgDki5': {'name': "I Hope You Don't Mind If I Come Here to Cry",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 41,
#   'duration_ms': 51069},
#  '6IWTSv1HarcxE5JSgPuFgb': {'name': 'We Were Friends',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017-10-23',
#   'popularity': 42,
#   'duration_ms': 155428},
#  '3gfBrvyk35gtmZhjbSvNyb': {'name': "Don't Cry Kate",
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2016-11-15',
#   'popularity': 28,
#   'duration_ms': 192000},
#  '3GpX3pimbyQAF2jufyGoV8': {'name': 'Introduction',
#   'artistName': 'In Love With a Ghost',
#   'release_date': '2017',
#   'popularity': 32,
#   'duration_ms': 36388},
#  '6IFEVo4pLKw67EYa1iEDle': {'name': '12:05am',
#   'artistName': 'The Deli',
#   'release_date': '2016-10-17',
#   'popularity': 30,
#   'duration_ms': 159831},
#  '1M1aKmgUXpmWZi43u8sJn4': {'name': 'Marble Soda',
#   'artistName': 'Shawn Wasabi',
#   'release_date': '2015-06-22',
#   'popularity': 0,
#   'duration_ms': 161919},
#  '7wDZGwj5hUwGScBlY1iBIo': {'name': 'Weekend',
#   'artistName': 'Gyvus',
#   'release_date': '2015-11-30',
#   'popularity': 0,
#   'duration_ms': 163764},
#  '6UFZBPUhfvkN4JRAJ5vOLQ': {'name': 'Grass',
#   'artistName': 'baaskaT',
#   'release_date': '2016-11-07',
#   'popularity': 0,
#   'duration_ms': 96923},
#  '4kVmLlBnLcfXIZIIhq3VUq': {'name': 'Her',
#   'artistName': 'eery',
#   'release_date': '2016-01-01',
#   'popularity': 0,
#   'duration_ms': 123207},
#  '0WFgSYnXkvKNQudrPe1Oym': {'name': 'azalea',
#   'artistName': 'eevee',
#   'release_date': '2016-12-01',
#   'popularity': 0,
#   'duration_ms': 115299},
#  '07yx1qShTYZ6Eq5yvLEQUg': {'name': '1:47am',
#   'artistName': 'The Deli',
#   'release_date': '2016-10-17',
#   'popularity': 36,
#   'duration_ms': 140237},
#  '6oTZJx62mCTt7p3LEqxcT0': {'name': 'Snowfall',
#   'artistName': 'Idealism',
#   'release_date': '2016-12-19',
#   'popularity': 0,
#   'duration_ms': 176500},
#  '26xgfuQnTaa5UQJhdQACz6': {'name': 'Forget',
#   'artistName': 'Pogo',
#   'release_date': '2015-06-11',
#   'popularity': 61,
#   'duration_ms': 164703},
#  '24Jk4wYlLRXI9TUMdkHoMN': {'name': 'Again',
#   'artistName': 'Wun Two',
#   'release_date': '2014-12-19',
#   'popularity': 0,
#   'duration_ms': 143132},
#  '7ydeKIGuAdxqkp7OsWGZx6': {'name': "We Can't Be Friends",
#   'artistName': 'Dream Koala',
#   'release_date': '2012-08-15',
#   'popularity': 0,
#   'duration_ms': 208451},
#  '4s2lS4q7UAwpqynFpxCKjH': {'name': 'Tyner',
#   'artistName': 'The Deli',
#   'release_date': '2016-10-17',
#   'popularity': 28,
#   'duration_ms': 163281},
#  '2li2YIAG0WR8wlkgyUbmST': {'name': 'Lonely',
#   'artistName': 'Idealism',
#   'release_date': '2017-02-13',
#   'popularity': 0,
#   'duration_ms': 119901},
#  '4adfpXRxA7q41AnkIRjTep': {'name': 'Souvenirs',
#   'artistName': 'Dream Koala',
#   'release_date': '2012-09-01',
#   'popularity': 0,
#   'duration_ms': 187392},
#  '6JtvXsOCLxILwhVaHS2nCC': {'name': 'Tell Me - Qrion Remix',
#   'artistName': 'Giraffage',
#   'release_date': '2015-08-14',
#   'popularity': 0,
#   'duration_ms': 259404},
#  '4EHkL0jkgTpG7Ri85LAXtg': {'name': 'Morning Ritual',
#   'artistName': "L'Indécis",
#   'release_date': '2016-02-15',
#   'popularity': 0,
#   'duration_ms': 92259},
#  '299vmLW2iaQxe8y9HLWNiH': {'name': 'just ask',
#   'artistName': 'weird inside',
#   'release_date': '2015-05-22',
#   'popularity': 45,
#   'duration_ms': 173846},
#  '29uGke73C3JUzciyUBRrkD': {'name': 'Finding Parking',
#   'artistName': 'Joey Pecoraro',
#   'release_date': '2017-02-22',
#   'popularity': 0,
#   'duration_ms': 172500},
#  '1louJpMmzEicAn7lzDalPW': {'name': 'No Promises (feat. Demi Lovato)',
#   'artistName': 'Cheat Codes',
#   'release_date': '2017-03-31',
#   'popularity': 67,
#   'duration_ms': 223503},
#  '2zDt2TfQbxiSPjTVJTgbwz': {'name': 'Starving',
#   'artistName': 'Hailee Steinfeld',
#   'release_date': '2016-07-22',
#   'popularity': 0,
#   'duration_ms': 181880},
#  '3jK5ndIlxMK3rN0gjlfkzh': {'name': 'Anganku Anganmu',
#   'artistName': 'Raisa',
#   'release_date': '2017-03-30',
#   'popularity': 48,
#   'duration_ms': 271467},
#  '167NczpNbRF7oWakJaY3Hh': {'name': 'Slow Hands',
#   'artistName': 'Niall Horan',
#   'release_date': '2017-05-04',
#   'popularity': 0,
#   'duration_ms': 188174},
#  '2Gl0FzuLxflY6nPifJp5Dr': {'name': 'First Time',
#   'artistName': 'Kygo',
#   'release_date': '2017-04-28',
#   'popularity': 68,
#   'duration_ms': 193511},
#  '0Oa9mHOnH14GZ4toWwkf4c': {'name': 'Good Life (with G-Eazy & Kehlani)',
#   'artistName': 'G-Eazy',
#   'release_date': '2017-03-17',
#   'popularity': 66,
#   'duration_ms': 225520},
#  '3s8ik4CUIZXXGDBgD0EAZ5': {'name': 'All Good',
#   'artistName': 'Dipha Barus',
#   'release_date': '2017-03-08',
#   'popularity': 48,
#   'duration_ms': 193160},
#  '4uoumbAMEMaKdtiv763jKz': {'name': 'TG4M',
#   'artistName': 'Zara Larsson',
#   'release_date': '2017-03-17',
#   'popularity': 49,
#   'duration_ms': 172893},
#  '72Q0FQQo32KJloivv5xge2': {'name': "I'm the One",
#   'artistName': 'DJ Khaled',
#   'release_date': '2017-04-27',
#   'popularity': 1,
#   'duration_ms': 288876},
#  '2oFQqo6YyVeQDTpVjhUfwE': {'name': 'Stryman',
#   'artistName': 'baaskaT',
#   'release_date': '2017-03-15',
#   'popularity': 0,
#   'duration_ms': 117735},
#  '6tuZKBiS1p6Ig0UtC0ii0Y': {'name': "I'm sorry (feat. shiloh)",
#   'artistName': 'Swell',
#   'release_date': '2016-01-20',
#   'popularity': 0,
#   'duration_ms': 157524},
#  '2S4N7RYlhHr1vWadDaleuJ': {'name': 'Burnt Rice (feat. Yung GEMMY)',
#   'artistName': 'Shawn Wasabi',
#   'release_date': '2015-12-04',
#   'popularity': 51,
#   'duration_ms': 120750},
#  '6RQFej8jDkNZIWc625nTKX': {'name': 'Fuck That Bitch',
#   'artistName': 'Gangsta Rap',
#   'release_date': '2007-05-15',
#   'popularity': 30,
#   'duration_ms': 186540},
#  '7iL6o9tox1zgHpKUfh9vuC': {'name': 'In Da Club',
#   'artistName': '50 Cent',
#   'release_date': '2003-02-06',
#   'popularity': 85,
#   'duration_ms': 193466},
#  '29NjaVT0UIw4Jc4HK21C0Y': {'name': 'Black Beatles',
#   'artistName': 'Rae Sremmurd',
#   'release_date': '2016-08-12',
#   'popularity': 0,
#   'duration_ms': 291866},
#  '2KWc5DKUCdoIMVIgivR1bb': {'name': 'Black Beatles - Rock',
#   'artistName': 'Our Last Night',
#   'release_date': '2017-01-17',
#   'popularity': 42,
#   'duration_ms': 241773},
#  '3Rx2h3qPbTOqvu8DEuIMQs': {'name': 'Nothing but a "G" Thang',
#   'artistName': 'Sean C. Johnson',
#   'release_date': '2015-03-10',
#   'popularity': 24,
#   'duration_ms': 223733},
#  '5qQ2Bnai4C9NQ1vWBl7yeX': {'name': 'Smoke Weed Everyday (feat. Diezel)',
#   'artistName': 'Trick Trick',
#   'release_date': '2013-01-08',
#   'popularity': 41,
#   'duration_ms': 229434},
#  '68hGjYI63KZXgCYicSMWHD': {'name': 'Turun Tetapi Naik',
#   'artistName': 'Jeffrey Rachmat',
#   'release_date': '2004',
#   'popularity': 0,
#   'duration_ms': 3053106},
#  '7cuu0RqA5ZXghqrD202NZB': {'name': 'Turun Naik Oles Trus',
#   'artistName': 'Fresh Boy',
#   'release_date': '2017-05-02',
#   'popularity': 0,
#   'duration_ms': 392751},
#  '4ZaSwueqdMGHr8z0oQSkMn': {'name': 'Seperti Babi',
#   'artistName': 'The Panasdalam',
#   'release_date': '2014-01-09',
#   'popularity': 32,
#   'duration_ms': 186053},
#  '5yEPxDjbbzUzyauGtnmVEC': {'name': 'Bitter Sweet Symphony',
#   'artistName': 'The Verve',
#   'release_date': '1997-09-29',
#   'popularity': 0,
#   'duration_ms': 358426},
#  '2NeHnSFnwNp1Z5WYgcjJ8L': {'name': "X Gon' Give It To Ya",
#   'artistName': 'DMX',
#   'release_date': '2010-01-01',
#   'popularity': 0,
#   'duration_ms': 219253},
#  '2oTDOIAdsxPTE7yAp4YOcv': {'name': 'Jump Around',
#   'artistName': 'House Of Pain',
#   'release_date': '1992',
#   'popularity': 3,
#   'duration_ms': 214946},
#  '3u9fHuAtjMY1RW2mZfO4Cf': {'name': "Gangsta's Paradise (feat. L.V.)",
#   'artistName': 'Coolio',
#   'release_date': '1995-11-07',
#   'popularity': 5,
#   'duration_ms': 241933},
#  '0s6Yxg9h7eW4M13rDq2N7Z': {'name': 'Lose Yourself',
#   'artistName': 'Eminem',
#   'release_date': '2014-11-24',
#   'popularity': 49,
#   'duration_ms': 320573},
#  '6HHytHLXLX8QfWTtGfFSvH': {'name': "Drop It Like It's Hot",
#   'artistName': 'Snoop Dogg',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 266066},
#  '6IkCht32pbDskKd8NWzWBF': {'name': 'Dat $tick',
#   'artistName': 'Rich Brian',
#   'release_date': '2016-02-17',
#   'popularity': 0,
#   'duration_ms': 126768},
#  '1YTz8nFEQi7t0VeZ1ppvy0': {'name': 'Dat $tick (Remix) (feat. Ghostface Killah & Pouya)',
#   'artistName': 'Rich Brian',
#   'release_date': '2016-10-13',
#   'popularity': 43,
#   'duration_ms': 197812},
#  '1XSvndyw6uqVW1ekRZsJUp': {'name': 'Who That Be',
#   'artistName': 'Rich Brian',
#   'release_date': '2016-08-09',
#   'popularity': 48,
#   'duration_ms': 134879},
#  '527KhZRk72NqSOduoJpXV6': {'name': 'Who That Be (Josh Pan & West1ne Remix)',
#   'artistName': 'Rich Brian',
#   'release_date': '2016-12-06',
#   'popularity': 28,
#   'duration_ms': 172962},
#  '7uuBfgY1vBCalrQRyyQhqs': {'name': 'Gospel',
#   'artistName': 'Rich Brian',
#   'release_date': '2017-05-12',
#   'popularity': 2,
#   'duration_ms': 173294},
#  '51OepvVuCOodoHfTi70hkl': {'name': 'Rintihan Kuntilanak',
#   'artistName': 'The Panasdalam',
#   'release_date': '2014-01-09',
#   'popularity': 23,
#   'duration_ms': 283160},
#  '1hPNdCII2b8NOEIqwbbsdG': {'name': '流星雨',
#   'artistName': 'F4',
#   'release_date': '2001-08-27',
#   'popularity': 55,
#   'duration_ms': 276600},
#  '0sjlALfgJkLnR7TVJOEuds': {'name': 'Ask For More',
#   'artistName': 'F4',
#   'release_date': '2006-12-18',
#   'popularity': 35,
#   'duration_ms': 239613},
#  '1WUQih0Npms0jQbn7XJQ2L': {'name': 'Suka Dukaku Mencari Lala',
#   'artistName': 'The Panasdalam',
#   'release_date': '2014-01-09',
#   'popularity': 19,
#   'duration_ms': 232560},
#  '5xV0rdDoqA9PtBmb0Dl3LM': {'name': 'Pulang Mabok',
#   'artistName': 'The Panasdalam',
#   'release_date': '2014-01-09',
#   'popularity': 30,
#   'duration_ms': 196360},
#  '7Izr83kICU3jNIkZKfxbbe': {'name': 'Djatinangor',
#   'artistName': 'The Panasdalam',
#   'release_date': '2014-01-09',
#   'popularity': 41,
#   'duration_ms': 190040},
#  '3WvpuN7JdO0AeUwhJQzKs3': {'name': 'Suci Dalam Debu',
#   'artistName': 'Iklim',
#   'release_date': '1997-04-12',
#   'popularity': 55,
#   'duration_ms': 286973},
#  '0sbCWA5D6rpVNTz5NU0gCZ': {'name': 'Inikah Cinta',
#   'artistName': 'Razis Ismail',
#   'release_date': '2015-12-18',
#   'popularity': 0,
#   'duration_ms': 260546},
#  '4HM7F8ymm5Ice2If8vRUfl': {'name': 'Lepaskan Diriku',
#   'artistName': 'J-Rocks',
#   'release_date': '2005-05-16',
#   'popularity': 57,
#   'duration_ms': 236960},
#  '4Ua1jF6VlaoyjDECHnr2CC': {'name': 'Cinderella',
#   'artistName': 'Radja',
#   'release_date': '2009',
#   'popularity': 0,
#   'duration_ms': 212137},
#  '4ST8t9M814FsyRtT9GvmDM': {'name': 'Tak Bisakah',
#   'artistName': 'Peterpan',
#   'release_date': '2008-01-01',
#   'popularity': 23,
#   'duration_ms': 214480},
#  '408TyH9YoTkH9J0Da9Ue8C': {'name': 'Manusia Bodoh',
#   'artistName': 'Ada Band',
#   'release_date': '2004-10-28',
#   'popularity': 0,
#   'duration_ms': 257927},
#  '7kylbMIrSPy7BkwOO01NDi': {'name': 'Piknik 72',
#   'artistName': 'Naif',
#   'release_date': '2014-07-03',
#   'popularity': 46,
#   'duration_ms': 204653},
#  '4fBFN8NLLIbvw6JzaiD2hp': {'name': 'Jikalau',
#   'artistName': 'Naif',
#   'release_date': '2014-07-03',
#   'popularity': 68,
#   'duration_ms': 186933},
#  '0Z3E3USDNRILRhQBwy0ljP': {'name': 'Air & Api',
#   'artistName': 'Naif',
#   'release_date': '2014-07-03',
#   'popularity': 71,
#   'duration_ms': 197813},
#  '63tUGwq0yrWE6FVemfPps9': {'name': 'Cinta Ini Membunuhku',
#   'artistName': 'D’MASIV',
#   'release_date': '2008-01-01',
#   'popularity': 22,
#   'duration_ms': 243706},
#  '53epbNYjH2elPuHjpqRSUk': {'name': 'Cinta Ini Membunuhku',
#   'artistName': 'D’MASIV',
#   'release_date': '2016-01-01',
#   'popularity': 64,
#   'duration_ms': 243706},
#  '0lliSgyvlOJ3wSFOeoAkeD': {'name': 'Rindu 1/2 Mati',
#   'artistName': 'D’MASIV',
#   'release_date': '2016-01-01',
#   'popularity': 24,
#   'duration_ms': 279880},
#  '3EELZDQN6F4eKmSOYnBddR': {'name': 'Sedang Ingin Bercinta',
#   'artistName': 'Dewa 19',
#   'release_date': '2016-09-27',
#   'popularity': 0,
#   'duration_ms': 240001},
#  '4WK6MkLU35rIwzXGbtVJ21': {'name': 'Lelaki Pencemburu',
#   'artistName': 'Dewa 19',
#   'release_date': '2016-09-27',
#   'popularity': 0,
#   'duration_ms': 256162},
#  '723lbdrLmSHUzgpsZ3tc4D': {'name': 'Dewi',
#   'artistName': 'Dewa 19',
#   'release_date': '2016-09-27',
#   'popularity': 0,
#   'duration_ms': 261363},
#  '4O2w5lBjUmvkSfdmN91JqQ': {'name': 'Angin',
#   'artistName': 'Dewa 19',
#   'release_date': '2007',
#   'popularity': 0,
#   'duration_ms': 252029},
#  '41dswHw9sCLChDgXyVS4kC': {'name': 'Asal Kau Bahagia',
#   'artistName': 'Armada',
#   'release_date': '2017-02-03',
#   'popularity': 0,
#   'duration_ms': 245067},
#  '2CulJODngVvPoLtQrZVWoy': {'name': 'Mau Dibawa Kemana',
#   'artistName': 'Armada',
#   'release_date': '2009-07-23',
#   'popularity': 65,
#   'duration_ms': 239573},
#  '3821tdFqPQeJNYxryIqIev': {'name': 'Hijrah Ke London',
#   'artistName': 'The Changcuters',
#   'release_date': '2008-02-08',
#   'popularity': 62,
#   'duration_ms': 205706},
#  '7ADK1rnMzP6PGWhoqWirBJ': {'name': 'Pupus',
#   'artistName': 'Dewa',
#   'release_date': '2002-04-05',
#   'popularity': 71,
#   'duration_ms': 305906},
#  '3tGIQoi9m0WfRfUYN49V7d': {'name': 'Elang',
#   'artistName': 'Dewa 19',
#   'release_date': '1999-10-26',
#   'popularity': 58,
#   'duration_ms': 261093},
#  '2F8nJ7yF9GN5ONBHnmzy1h': {'name': 'Racun Dunia',
#   'artistName': 'The Changcuters',
#   'release_date': '2008-02-08',
#   'popularity': 64,
#   'duration_ms': 274466},
#  '7z1xSflxvmyflUrvnBhBEo': {'name': 'Api & Lentera',
#   'artistName': 'Barasuara',
#   'release_date': '2015-10-16',
#   'popularity': 0,
#   'duration_ms': 263637},
#  '7A8nbMMgzEeX0JKOjKXp8N': {'name': 'Bahas Bahasa',
#   'artistName': 'Barasuara',
#   'release_date': '2015-10-16',
#   'popularity': 0,
#   'duration_ms': 268854},
# ...
#   'artistName': 'Don Nelson',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 116760},
#  '1xUNtz2aVvPLsUUDl4mdRq': {'name': 'Spotless Mind - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 71533},
#  '12WLu27c3DKtOBRFC2K6yH': {'name': 'Peer Pressure - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 72026},
#  '5Il3NSnc9B7nmmTdW8gkoB': {'name': 'Phone Call - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 62600},
#  '0ip8ZHhDfy5MlBqCeNW9yJ': {'name': 'Bookstore - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 52093},
#  '0VURafS5qf6a1kHjYPGoW6': {'name': "Section 2 (It's The Sun) (KCRW) - Live",
#   'artistName': 'The Polyphonic Spree',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 333306},
#  '6IcDx3wme2bNM4E8i0c1up': {'name': 'Down The Drain - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 54573},
#  '5jJxhzv2u17T5qr6nlHnec': {'name': 'Postcard - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 22760},
#  '6FIlS9ZNQreZYj3Xn8Ai8n': {'name': 'Collecting Things - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 73866},
#  '0tO5ub8Y9kkWSmF43yfGIi': {'name': 'Drive In - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 138973},
#  '1uUYRXg32hkJpXODSXOOpd': {'name': 'A Dream Upon Waking - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 215466},
#  '1Jt4m2eUxSomYoBZROTJxI': {'name': 'Elephant Parade - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 26293},
#  '1QuxqahtWdRH29jlzQcTLR': {'name': 'Something - Original Version',
#   'artistName': 'The Willowz',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 143333},
#  '5eVJuxBHkSKp5J28YmyOOd': {'name': 'Sidewalk Fight - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 31626},
#  '4UnbgD5MFtE3tpXNUvYbb2': {'name': 'Row - Score',
#   'artistName': 'Jon Brion',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 59933},
#  '0BXycyK9U7uBwfDOGWGLAs': {'name': 'Light & Day - Radio Edit',
#   'artistName': 'The Polyphonic Spree',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 182973},
#  '1NF5wFa3hrlgTsoOhET1jT': {'name': 'I Wonder - Original Version',
#   'artistName': 'The Willowz',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 175973},
#  '3wMbTfeHSM087geacW9VGq': {'name': 'Some Kinda Shuffle - Instrumental',
#   'artistName': 'Don Nelson',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 130933},
#  '7bh969wFgIfZJNRGAO224A': {'name': 'Wada Na Tod - From "Dil Tujhko Diya"',
#   'artistName': 'Lata Mangeshkar',
#   'release_date': '2004-01-01',
#   'popularity': 0,
#   'duration_ms': 354560},
#  '3hGB6zmV7vI5jPAJxTW6Br': {'name': 'Otter Pop',
#   'artistName': 'Shawn Wasabi',
#   'release_date': '2017-07-13',
#   'popularity': 39,
#   'duration_ms': 167741},
#  '4MJcQ9uAHcMp7AXrSWsmlV': {'name': 'Dont Let Me Fall Asleep',
#   'artistName': 'Alicks',
#   'release_date': '2017-03-16',
#   'popularity': 32,
#   'duration_ms': 328751},
#  '3ly2k3a5KQvyOUtbeA7rkD': {'name': 'From Here',
#   'artistName': 'Adib Sin',
#   'release_date': '2017-01-26',
#   'popularity': 0,
#   'duration_ms': 206000},
#  '55Bcml8WzcfNUyqZ7IrhY3': {'name': 'New Place to Begin',
#   'artistName': 'khai dreams',
#   'release_date': '2017-09-23',
#   'popularity': 0,
#   'duration_ms': 138461},
#  '7qBGEiUWgxm50Qtqj0bI60': {'name': 'Chocoholic',
#   'artistName': 'Tomggg',
#   'release_date': '2015-03-18',
#   'popularity': 0,
#   'duration_ms': 340454},
#  '6sFwwi8SsbfiWbHfpyht8w': {'name': 'Puzzle',
#   'artistName': 'Limbo',
#   'release_date': '2018-01-08',
#   'popularity': 0,
#   'duration_ms': 135000},
#  '2oZNXWTmn3G6uxNyPq9ej5': {'name': 'In Love',
#   'artistName': 'khai dreams',
#   'release_date': '2018-02-12',
#   'popularity': 0,
#   'duration_ms': 69389},
#  '1tJ4fzm6PnlldHJ51yo0AO': {'name': 'When I Look Into Your Eyes',
#   'artistName': 'khai dreams',
#   'release_date': '2018-02-14',
#   'popularity': 0,
#   'duration_ms': 150375},
#  '7zqsDgTydxCAvBMqkuEbO7': {'name': 'Butter Sugar Cream (feat. tsvaci)',
#   'artistName': 'Tomggg',
#   'release_date': '2015-03-18',
#   'popularity': 0,
#   'duration_ms': 296888},
#  '5eboNEy0WMkLRnPs56xBfF': {'name': 'future hippie',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 27,
#   'duration_ms': 262279},
#  '2HiyU8x22ZsrLHxhF59pIf': {'name': 'Mind - Tomggg Remix',
#   'artistName': 'Slow Magic',
#   'release_date': '2017-09-01',
#   'popularity': 0,
#   'duration_ms': 189252},
#  '25uai4dFpLc2MgDL4jwbS9': {'name': 'Sala',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 18,
#   'duration_ms': 282079},
#  '159AnVj9IVGu4JmZT4ZuYe': {'name': 'Love is Over - (Tomggg Remix)',
#   'artistName': 'chelmico',
#   'release_date': '2018-01-17',
#   'popularity': 26,
#   'duration_ms': 235826},
#  '6andM0aH8b48t6ZxKEDw4J': {'name': 'Curtain Fig',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 15,
#   'duration_ms': 308679},
#  '5yATCUkZlKVdSZDTol5PQo': {'name': 'Caramel Popcorn (feat. Phoenix Troy)',
#   'artistName': 'Tomggg',
#   'release_date': '2015-03-18',
#   'popularity': 0,
#   'duration_ms': 288000},
#  '349hPOgxfnz832M6zFHX7M': {'name': 'Butter Sugar Cream (MAXO Beammix)',
#   'artistName': 'Tomggg',
#   'release_date': '2015-03-18',
#   'popularity': 0,
#   'duration_ms': 158309},
#  '48S7Snu6dGyo48MqBtrwOU': {'name': 'Wedding Cake',
#   'artistName': 'Tomggg',
#   'release_date': '2015-03-18',
#   'popularity': 0,
#   'duration_ms': 256614},
#  '6NG8A24yd1nYl9gVhcfC7L': {'name': 'Tick Tock Skip Drop',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 10,
#   'duration_ms': 335419},
#  '0E5pNzt2pwd3bOqQsOnfQv': {'name': 'Tick Tock Skip Drop - Mili remix',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 4,
#   'duration_ms': 308961},
#  '2AdFWDzjmdMeH57ZuFldSZ': {'name': 'Tick Tock Skip Drop (instrumental)',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 6,
#   'duration_ms': 334840},
#  '4IZDfqXRGWinR2zuhzbN7B': {'name': 'Sala (instrumental)',
#   'artistName': 'Tomggg',
#   'release_date': '2016-05-25',
#   'popularity': 5,
#   'duration_ms': 283239},
#  '4Pn1ztkwMZbzQOQxqRyqfZ': {'name': 'Wire Frame Baby (feat. MAMIKO[chelmico])',
#   'artistName': 'Yasutaka Nakata',
#   'release_date': '2018-02-05',
#   'popularity': 26,
#   'duration_ms': 243946},
#  '3YUbflPp2rUKIDjiUQAd13': {'name': 'Yume De Mata Aetaranaa',
#   'artistName': 'Yunomi',
#   'release_date': '2016-10-12',
#   'popularity': 31,
#   'duration_ms': 197250},
#  '6NgBiZKYX52IGZvT92025F': {'name': 'Rest',
#   'artistName': 'Pheeno',
#   'release_date': '2016-12-14',
#   'popularity': 33,
#   'duration_ms': 185333},
#  '5KOocgCGwqyaC1kSHD0tz7': {'name': 'toward morning',
#   'artistName': 'in the blue shirt',
#   'release_date': '2017-09-24',
#   'popularity': 0,
#   'duration_ms': 259707},
#  '1jsuNY2norISRscbYj5ISS': {'name': 'さみしいかみさま',
#   'artistName': 'Daoko',
#   'release_date': '2017-12-20',
#   'popularity': 44,
#   'duration_ms': 269663},
#  '5nfr8CQxhR2xKmyI5hy9sK': {'name': 'Wind Bell',
#   'artistName': 'in the blue shirt',
#   'release_date': '2016-10-05',
#   'popularity': 18,
#   'duration_ms': 156400},
#  '3xA7q8yI1Lq9GAPyzrF9yZ': {'name': 'Hotto Dogu',
#   'artistName': 'Shawn Wasabi',
#   'release_date': '2015-06-22',
#   'popularity': 33,
#   'duration_ms': 237450},
#  '1WfJ6JyQ3prYlxXXnVxtWz': {'name': 'Unfair',
#   'artistName': 'Instupendo',
#   'release_date': '2016-06-10',
#   'popularity': 33,
#   'duration_ms': 82473},
#  '3ijrrM0lNOXCJBBrsVhcLZ': {'name': 'Airwaves',
#   'artistName': 'Adib Sin',
#   'release_date': '2017-04-07',
#   'popularity': 42,
#   'duration_ms': 192000},
#  '4hbAPzoCrnmVfpswf1Nfos': {'name': 'ナツゾラ',
#   'artistName': 'HoneyComeBear',
#   'release_date': '2018-01-15',
#   'popularity': 0,
#   'duration_ms': 213750},
#  '557y7PDrfoG7ZiXE82XPxp': {'name': 'Empyrean',
#   'artistName': 'City Girl',
#   'release_date': '2018-04-02',
#   'popularity': 26,
#   'duration_ms': 208320},
#  '3sxTrGBmfjlMJIy3QaxsTP': {'name': 'Sleeping with You',
#   'artistName': 'dark cat',
#   'release_date': '2017-09-24',
#   'popularity': 0,
#   'duration_ms': 150360},
#  '0cmpaEz9k3FCpXrZeG6zE6': {'name': 'すてきなメゾン feat. 玉城ティナ',
#   'artistName': 'tofubeats',
#   'release_date': '2015-09-16',
#   'popularity': 38,
#   'duration_ms': 251386},
#  '2x4ZC6OpEvud8HayLpceue': {'name': 'Harvest Moon',
#   'artistName': 'Mree',
#   'release_date': '2017-10-13',
#   'popularity': 0,
#   'duration_ms': 206391},
#  '6j236RwzFFj4wqH2tWJNBD': {'name': "5 O'Clock (feat. Lily Allen & Wiz Khalifa)",
#   'artistName': 'T-Pain',
#   'release_date': '2011-09-23',
#   'popularity': 0,
#   'duration_ms': 281533},
#  '1mr3616BzLdhXfJmLmRsO8': {'name': 'Fireflies',
#   'artistName': 'Owl City',
#   'release_date': '2009-01-01',
#   'popularity': 0,
#   'duration_ms': 228346},
#  '7cE8VabTiFSjD2FSf6xrOx': {'name': 'The Imperial March - Pegboard Nerds Remix',
#   'artistName': 'Celldweller',
#   'release_date': '2018-05-04',
#   'popularity': 28,
#   'duration_ms': 263448},
#  '4rKTvV3QCEwhmnrxcw6PGn': {'name': 'The Imperial March (Pegboard Nerds Remix) - Instrumental',
#   'artistName': 'Celldweller',
#   'release_date': '2018-05-04',
#   'popularity': 17,
#   'duration_ms': 263448},
#  '6Rvpcw4OnG9fMfcxVIyEhL': {'name': "You Can't Stop this Mother F*****",
#   'artistName': 'Tyler Bates',
#   'release_date': '2018-05-11',
#   'popularity': 23,
#   'duration_ms': 70600},
#  '0vwETfTihkeOWR7ChJ7KFe': {'name': 'Ice Box',
#   'artistName': 'Tyler Bates',
#   'release_date': '2018-05-11',
#   'popularity': 4,
#   'duration_ms': 79186},
#  '6nbVSUTp2Ucku7TXMtgiTd': {'name': 'Weasel Interrogation',
#   'artistName': 'Tyler Bates',
#   'release_date': '2018-05-11',
#   'popularity': 4,
#   'duration_ms': 71760},
#  '5hQll2t2rfpVARhVjDVOYJ': {'name': 'Oddloop',
#   'artistName': 'frederic',
#   'release_date': '2014-09-24',
#   'popularity': 59,
#   'duration_ms': 255293},
#  '2ofTMnXr1F24XmXCdKUfmM': {'name': 'Uwasa No Kemuri No Onnanoko',
#   'artistName': 'frederic',
#   'release_date': '2014-09-24',
#   'popularity': 23,
#   'duration_ms': 214213},
#  '26sfOdUbSSm6nnmcuXL61P': {'name': 'Take Me on (feat. Clara C)',
#   'artistName': 'New Heights',
#   'release_date': '2011-09-25',
#   'popularity': 17,
#   'duration_ms': 235086},
#  '70hvCk6sUutFjKA1Y4W1mc': {'name': 'take me on',
#   'artistName': 'joan',
#   'release_date': '2017-01-24',
#   'popularity': 0,
#   'duration_ms': 210840},
#  '2WfaOiMkCvy7F5fcp2zZ8L': {'name': 'Take on Me',
#   'artistName': 'a-ha',
#   'release_date': '1985-06-01',
#   'popularity': 89,
#   'duration_ms': 225280},
#  '7CFN1zqKSjucIyDzcrqE6I': {'name': 'Take On Me - MTV Unplugged',
#   'artistName': 'a-ha',
#   'release_date': '2017-10-06',
#   'popularity': 0,
#   'duration_ms': 253906},
#  '5st5644IlBmKiiRE73UsoZ': {'name': 'Fuck You',
#   'artistName': 'Lily Allen',
#   'release_date': '2009-01-26',
#   'popularity': 63,
#   'duration_ms': 219893},
#  '76FnCkhueYsfbyTv5Rm65B': {'name': "Who'd Have Known",
#   'artistName': 'Lily Allen',
#   'release_date': '2009-01-26',
#   'popularity': 39,
#   'duration_ms': 230986},
#  '6IFXwxWeLkeQ68XaUAcxUf': {'name': 'Chinese',
#   'artistName': 'Lily Allen',
#   'release_date': '2009-01-26',
#   'popularity': 37,
#   'duration_ms': 208213},
#  '56N9s9PS6VwGolUnx1CJkv': {'name': 'Somewhere Only We Know',
#   'artistName': 'Lily Allen',
#   'release_date': '2014-05-02',
#   'popularity': 64,
#   'duration_ms': 208504},
#  '79z9QkhHePTFsSeVw9uyj0': {'name': 'Smile',
#   'artistName': 'Lily Allen',
#   'release_date': '2006-07-14',
#   'popularity': 72,
#   'duration_ms': 196893},
#  '5wD6de7Fz1QfxVNkv1SEy7': {'name': 'LDN',
#   'artistName': 'Lily Allen',
#   'release_date': '2006-07-14',
#   'popularity': 62,
#   'duration_ms': 190773},
#  '1cDRpJiJa94Voj0Ayc9iGJ': {'name': 'Not Fair',
#   'artistName': 'Lily Allen',
#   'release_date': '2009-01-26',
#   'popularity': 55,
#   'duration_ms': 202546},
#  '4OLVK3kktkdLPp8dDgoCtb': {'name': 'Angel By The Wings',
#   'artistName': 'Sia',
#   'release_date': '2016-12-02',
#   'popularity': 67,
#   'duration_ms': 319200},
#  '58zsLZPvfflaiIbNWoA22O': {'name': 'Human',
#   'artistName': "Rag'n'Bone Man",
#   'release_date': '2017-02-10',
#   'popularity': 82,
#   'duration_ms': 200186},
#  '6UFr9KANWaH5jiB9PIPS9C': {'name': 'I Fear the Nite',
#   'artistName': 'Dan Romer',
#   'release_date': '2016-07-27',
#   'popularity': 0,
#   'duration_ms': 157493},
#  '0D2m3GX6mNfNB6dKJQjCgM': {'name': 'Take Care',
#   'artistName': 'Beach House',
#   'release_date': '2010-01-26',
#   'popularity': 49,
#   'duration_ms': 348440},
#  '7pzdiluN2tVrxsFGyM2Asc': {'name': 'I Lived',
#   'artistName': 'OneRepublic',
#   'release_date': '2013-01-01',
#   'popularity': 0,
#   'duration_ms': 234546},
#  '2ewOCJvEeaxihhUZdaucqQ': {'name': 'Control',
#   'artistName': 'Battle Tapes',
#   'release_date': '2017-07-14',
#   'popularity': 0,
#   'duration_ms': 190434},
#  '7lLKxcNeJtDTWVRKHovLEC': {'name': 'Build It Better',
#   'artistName': 'Aron Wright',
#   'release_date': '2015-03-19',
#   'popularity': 52,
#   'duration_ms': 234473},
#  '3Wd3mAficthmcUcCICvwSG': {'name': 'Down In The Valley',
#   'artistName': 'The Head And The Heart',
#   'release_date': '2010',
#   'popularity': 0,
#   'duration_ms': 303653},
#  '79cuOz3SPQTuFrp8WgftAu': {'name': "There's Nothing Holdin' Me Back",
#   'artistName': 'Shawn Mendes',
#   'release_date': '2017-04-20',
#   'popularity': 0,
#   'duration_ms': 199440},
#  '4Rwfg1x0g3cd5UwuK2UVLa': {'name': "Somebody's Someone",
#   'artistName': 'Daphne Willis',
#   'release_date': '2017-02-13',
#   'popularity': 24,
#   'duration_ms': 224349},
#  '2eha6iitIJ7EaVdvusgtQi': {'name': 'Run the Jewels',
#   'artistName': 'Run The Jewels',
#   'release_date': '2014-01-13',
#   'popularity': 0,
#   'duration_ms': 210626},
#  '1UQKGA5ZSetcDjdW3IMWnY': {'name': 'Forest',
#   'artistName': 'Rogue Wave',
#   'release_date': '2017-10-28',
#   'popularity': 31,
#   'duration_ms': 292076},
#  '4I18rXWixQBWc8JhTqx6Xn': {'name': "I Won't Let You Down",
#   'artistName': 'Erin McCarley',
#   'release_date': '2017-11-06',
#   'popularity': 40,
#   'duration_ms': 198344},
#  '7qVfJ6wvbtxjtqMrWbvcOo': {'name': 'Kennedy',
#   'artistName': 'Donovan Woods',
#   'release_date': '2013-03-26',
#   'popularity': 0,
#   'duration_ms': 108573},
#  '0ytCr0BRergKfjMYayYycg': {'name': 'Shine A Light',
#   'artistName': 'BANNERS',
#   'release_date': '2015-09-18',
#   'popularity': 0,
#   'duration_ms': 225120},
#  '5f8Cn4lVRMUL9sA8oYw3lu': {'name': "If Ever There's a Reason",
#   'artistName': 'Derby',
#   'release_date': '2008-06-24',
#   'popularity': 29,
#   'duration_ms': 239240},
#  '4XfaG7qBZ8qeyrTQ25uXJj': {'name': "I'll Be Your Mirror",
#   'artistName': 'Clem Snide',
#   'release_date': '2017-11-17',
#   'popularity': 35,
#   'duration_ms': 203000},
#  '5Z2TvUNflVYGsoFGkvAKzE': {'name': 'Without You',
#   'artistName': 'for KING & COUNTRY',
#   'release_date': '2015-10-22',
#   'popularity': 44,
#   'duration_ms': 292693},
#  '4T8FoNHY3UZSYgOV76ueVU': {'name': 'Ancient Light',
#   'artistName': 'Allman Brown',
#   'release_date': '2017-02-10',
#   'popularity': 41,
#   'duration_ms': 244900},
#  '0Kt5AHOpQAkEsHAuPeB0le': {'name': 'Sons and Daughters',
#   'artistName': 'Allman Brown',
#   'release_date': '2017-02-10',
#   'popularity': 50,
#   'duration_ms': 216052},
#  '2ZuiQ9Kn9O6v2hWs7cBBQ4': {'name': 'Ordinary Man',
#   'artistName': 'Eels',
#   'release_date': '2009-06-02',
#   'popularity': 0,
#   'duration_ms': 197746},
#  '56oReVXIfUO9xkX7pHmEU0': {'name': 'On the Nature of Daylight',
#   'artistName': 'Max Richter',
#   'release_date': '2018-05-11',
#   'popularity': 69,
#   'duration_ms': 371746},
#  '0XEUKN8CnHAKNmWmK1FG0d': {'name': 'The Heat',
#   'artistName': 'The Bones of J.R. Jones',
#   'release_date': '2016-04-15',
#   'popularity': 55,
#   'duration_ms': 194331},
#  ...}

# %%
track_info_df = pd.DataFrame.from_dict(track_info, orient='index')

# %%
track_info_df.to_csv('datasets/tracks_info_df.csv', index=False)

# %% [markdown]
# ## get track features

# %%
track_features = {}
for i in range(0, len(tracks_uri_list), 50):
    track_batch = tracks_uri_list[i:i+50]
    sapi = sp.audio_features(track_batch)
    for track in sapi:
        if track is not None:
            track_features[track['id']] = {'danceability':track['danceability'], 'energy':track['energy'], 'key':track['key'], 'loudness':track['loudness'], 'mode':track['mode'], 'speechiness':track['speechiness'], 'acousticness':track['acousticness'], 'instrumentalness':track['instrumentalness'], 'liveness':track['liveness'], 'valence':track['valence'], 'tempo':track['tempo'], 'time_signature':track['time_signature']}
        # we'll skip it if the track has no audio features data
    time.sleep(1)

# %%
len(track_features)
# Out:
# 5165

# %%
track_features
# Out:
# {'6tAM5c0bJOwRqGAEgiNMpI': {'danceability': 0.446,
#   'energy': 0.823,
#   'key': 11,
#   'loudness': -5.279,
#   'mode': 0,
#   'speechiness': 0.0859,
#   'acousticness': 0.00256,
#   'instrumentalness': 0.0748,
#   'liveness': 0.117,
#   'valence': 0.263,
#   'tempo': 128.198,
#   'time_signature': 4},
#  '5Q0P0cX3e42PgKd8LLS3ms': {'danceability': 0.402,
#   'energy': 0.856,
#   'key': 1,
#   'loudness': -4.256,
#   'mode': 1,
#   'speechiness': 0.0659,
#   'acousticness': 0.00504,
#   'instrumentalness': 0.0164,
#   'liveness': 0.253,
#   'valence': 0.247,
#   'tempo': 140.028,
#   'time_signature': 4},
#  '4VrdksXJVhAOLW49qV0VTQ': {'danceability': 0.426,
#   'energy': 0.915,
#   'key': 11,
#   'loudness': -3.881,
#   'mode': 0,
#   'speechiness': 0.143,
#   'acousticness': 0.000899,
#   'instrumentalness': 0.108,
#   'liveness': 0.495,
#   'valence': 0.271,
#   'tempo': 130.405,
#   'time_signature': 4},
#  '0ng42pTjKgskmobNzhnEUa': {'danceability': 0.434,
#   'energy': 0.839,
#   'key': 8,
#   'loudness': -4.493,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 0.0284,
#   'instrumentalness': 0.00103,
#   'liveness': 0.605,
#   'valence': 0.4,
#   'tempo': 127.67,
#   'time_signature': 4},
#  '1ip1SN4tWX0qMgE1KgIF52': {'danceability': 0.457,
#   'energy': 0.911,
#   'key': 1,
#   'loudness': -3.315,
#   'mode': 1,
#   'speechiness': 0.0498,
#   'acousticness': 0.00339,
#   'instrumentalness': 0.592,
#   'liveness': 0.0752,
#   'valence': 0.33,
#   'tempo': 175.002,
#   'time_signature': 4},
#  '05LCfd8s9n2teUcsTsBAnr': {'danceability': 0.672,
#   'energy': 0.856,
#   'key': 11,
#   'loudness': -5.537,
#   'mode': 1,
#   'speechiness': 0.262,
#   'acousticness': 0.0534,
#   'instrumentalness': 3.93e-05,
#   'liveness': 0.218,
#   'valence': 0.641,
#   'tempo': 180.048,
#   'time_signature': 4},
#  '1uy20tUwglZ4hapeq50jSL': {'danceability': 0.843,
#   'energy': 0.576,
#   'key': 2,
#   'loudness': -6.328,
#   'mode': 1,
#   'speechiness': 0.151,
#   'acousticness': 0.00295,
#   'instrumentalness': 0.895,
#   'liveness': 0.0644,
#   'valence': 0.633,
#   'tempo': 127.999,
#   'time_signature': 4},
#  '0EEWFu8Becr1CKzCljRiEG': {'danceability': 0.676,
#   'energy': 0.882,
#   'key': 7,
#   'loudness': -4.069,
#   'mode': 1,
#   'speechiness': 0.037,
#   'acousticness': 0.566,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.855,
#   'tempo': 143.005,
#   'time_signature': 4},
#  '2nYxM6Di7mhBTv26K887fQ': {'danceability': 0.391,
#   'energy': 0.472,
#   'key': 1,
#   'loudness': -4.121,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.316,
#   'instrumentalness': 0,
#   'liveness': 0.126,
#   'valence': 0.289,
#   'tempo': 175.968,
#   'time_signature': 4},
#  '4kFW3sV8K3YRYG04Qhxdjw': {'danceability': 0.702,
#   'energy': 0.949,
#   'key': 5,
#   'loudness': -4.132,
#   'mode': 1,
#   'speechiness': 0.089,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.0728,
#   'valence': 0.486,
#   'tempo': 123.988,
#   'time_signature': 4},
#  '6mPGkCjfAZ1PR52RBxXumL': {'danceability': 0.415,
#   'energy': 0.86,
#   'key': 7,
#   'loudness': -4.336,
#   'mode': 0,
#   'speechiness': 0.193,
#   'acousticness': 0.0842,
#   'instrumentalness': 0,
#   'liveness': 0.216,
#   'valence': 0.679,
#   'tempo': 104.207,
#   'time_signature': 4},
#  '167PWPhEUGgTXuRkRCCCSD': {'danceability': 0.625,
#   'energy': 0.827,
#   'key': 0,
#   'loudness': -4.327,
#   'mode': 0,
#   'speechiness': 0.0375,
#   'acousticness': 0.0335,
#   'instrumentalness': 0,
#   'liveness': 0.207,
#   'valence': 0.463,
#   'tempo': 125.949,
#   'time_signature': 4},
#  '3AyQKxtCEk3ZR3JRnEpuSe': {'danceability': 0.508,
#   'energy': 0.773,
#   'key': 5,
#   'loudness': -2.751,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.146,
#   'instrumentalness': 2.3e-06,
#   'liveness': 0.0792,
#   'valence': 0.498,
#   'tempo': 118.02,
#   'time_signature': 4},
#  '7piGheKcgabl2VgB1YkVEo': {'danceability': 0.629,
#   'energy': 0.602,
#   'key': 7,
#   'loudness': -6.579,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.477,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.757,
#   'tempo': 163.892,
#   'time_signature': 4},
#  '54PTOiC3MbDJGt9zpf6Jac': {'danceability': 0.698,
#   'energy': 0.709,
#   'key': 4,
#   'loudness': -3.373,
#   'mode': 1,
#   'speechiness': 0.0405,
#   'acousticness': 0.456,
#   'instrumentalness': 0,
#   'liveness': 0.298,
#   'valence': 0.528,
#   'tempo': 115.879,
#   'time_signature': 4},
#  '3IG6jyqLWwEyvPaGwEepcr': {'danceability': 0.713,
#   'energy': 0.881,
#   'key': 5,
#   'loudness': -3.594,
#   'mode': 1,
#   'speechiness': 0.0907,
#   'acousticness': 0.321,
#   'instrumentalness': 0,
#   'liveness': 0.3,
#   'valence': 0.922,
#   'tempo': 159.979,
#   'time_signature': 4},
#  '3nKu0IIjJLU4h1cM5eTBiQ': {'danceability': 0.606,
#   'energy': 0.358,
#   'key': 2,
#   'loudness': -7.327,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.734,
#   'instrumentalness': 0,
#   'liveness': 0.0851,
#   'valence': 0.489,
#   'tempo': 148.048,
#   'time_signature': 4},
#  '2kBR8dkyKfd25W9PRUFrLh': {'danceability': 0.593,
#   'energy': 0.741,
#   'key': 4,
#   'loudness': -5.078,
#   'mode': 0,
#   'speechiness': 0.305,
#   'acousticness': 0.247,
#   'instrumentalness': 0,
#   'liveness': 0.0983,
#   'valence': 0.545,
#   'tempo': 164.902,
#   'time_signature': 4},
#  '0skMV1gLpuvWFx1oKVBEkv': {'danceability': 0.502,
#   'energy': 0.755,
#   'key': 8,
#   'loudness': -5.857,
#   'mode': 1,
#   'speechiness': 0.794,
#   'acousticness': 0.0446,
#   'instrumentalness': 1.44e-05,
#   'liveness': 0.371,
#   'valence': 0.381,
#   'tempo': 170.14,
#   'time_signature': 4},
#  '1WSH5C56sRGwgbpH4cndH0': {'danceability': 0.582,
#   'energy': 0.509,
#   'key': 0,
#   'loudness': -7.301,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.402,
#   'instrumentalness': 0.126,
#   'liveness': 0.109,
#   'valence': 0.444,
#   'tempo': 174.976,
#   'time_signature': 4},
#  '19aFbIM6m8suZZnP0YDhW2': {'danceability': 0.739,
#   'energy': 0.638,
#   'key': 6,
#   'loudness': -6.466,
#   'mode': 1,
#   'speechiness': 0.0798,
#   'acousticness': 0.354,
#   'instrumentalness': 0,
#   'liveness': 0.145,
#   'valence': 0.36,
#   'tempo': 90.831,
#   'time_signature': 4},
#  '4mKaGkUNWrbDtvTl7sZDkt': {'danceability': 0.556,
#   'energy': 0.76,
#   'key': 6,
#   'loudness': -5.291,
#   'mode': 0,
#   'speechiness': 0.0482,
#   'acousticness': 0.00283,
#   'instrumentalness': 0.00741,
#   'liveness': 0.364,
#   'valence': 0.203,
#   'tempo': 131.983,
#   'time_signature': 4},
#  '0IavpjES4TgnNw2RPYDDey': {'danceability': 0.709,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.008,
#   'mode': 1,
#   'speechiness': 0.135,
#   'acousticness': 0.104,
#   'instrumentalness': 3.5e-05,
#   'liveness': 0.327,
#   'valence': 0.255,
#   'tempo': 91.999,
#   'time_signature': 4},
#  '15O20RQyWJgKrkHID9ynT9': {'danceability': 0.443,
#   'energy': 0.558,
#   'key': 0,
#   'loudness': -5.436,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'acousticness': 0.441,
#   'instrumentalness': 0,
#   'liveness': 0.163,
#   'valence': 0.248,
#   'tempo': 116.838,
#   'time_signature': 4},
#  '48qF1yaxtfOga12D6xR0Im': {'danceability': 0.614,
#   'energy': 0.956,
#   'key': 7,
#   'loudness': -2.693,
#   'mode': 0,
#   'speechiness': 0.057,
#   'acousticness': 0.0307,
#   'instrumentalness': 0.00316,
#   'liveness': 0.0854,
#   'valence': 0.199,
#   'tempo': 150.05,
#   'time_signature': 4},
#  '2bfGNzdiRa1jXZRdfssSzR': {'danceability': 0.625,
#   'energy': 0.877,
#   'key': 10,
#   'loudness': -7.176,
#   'mode': 0,
#   'speechiness': 0.162,
#   'acousticness': 0.0315,
#   'instrumentalness': 0.0811,
#   'liveness': 0.672,
#   'valence': 0.865,
#   'tempo': 192.296,
#   'time_signature': 4},
#  '26ZC396ABpfS0MIbOetGEV': {'danceability': 0.326,
#   'energy': 0.795,
#   'key': 9,
#   'loudness': -2.773,
#   'mode': 1,
#   'speechiness': 0.0419,
#   'acousticness': 0.0182,
#   'instrumentalness': 0,
#   'liveness': 0.356,
#   'valence': 0.423,
#   'tempo': 81.912,
#   'time_signature': 4},
#  '2QzQU3nEL5kcCI11o5AfmK': {'danceability': 0.634,
#   'energy': 0.871,
#   'key': 10,
#   'loudness': -4.804,
#   'mode': 0,
#   'speechiness': 0.0486,
#   'acousticness': 7.35e-05,
#   'instrumentalness': 0.56,
#   'liveness': 0.689,
#   'valence': 0.0692,
#   'tempo': 120.01,
#   'time_signature': 4},
#  '1Kny6fGX5BzfhI3emVgMVz': {'danceability': 0.522,
#   'energy': 0.931,
#   'key': 3,
#   'loudness': -4.646,
#   'mode': 1,
#   'speechiness': 0.0616,
#   'acousticness': 0.0935,
#   'instrumentalness': 7.05e-05,
#   'liveness': 0.103,
#   'valence': 0.457,
#   'tempo': 127.928,
#   'time_signature': 4},
#  '1Y4z9pcqHF9KHHnZQoB07O': {'danceability': 0.488,
#   'energy': 0.545,
#   'key': 7,
#   'loudness': -9.966,
#   'mode': 0,
#   'speechiness': 0.0706,
#   'acousticness': 0.799,
#   'instrumentalness': 0.768,
#   'liveness': 0.12,
#   'valence': 0.0969,
#   'tempo': 110.082,
#   'time_signature': 4},
#  '6rn7zSeV46JMH0hJa4JJ6O': {'danceability': 0.529,
#   'energy': 0.743,
#   'key': 0,
#   'loudness': -4.153,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.0422,
#   'instrumentalness': 1.08e-05,
#   'liveness': 0.115,
#   'valence': 0.17,
#   'tempo': 136.959,
#   'time_signature': 4},
#  '4AP0fHeJ9MRGiS1i1xlw7Y': {'danceability': 0.696,
#   'energy': 0.874,
#   'key': 8,
#   'loudness': -6.841,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 0.00848,
#   'instrumentalness': 0.104,
#   'liveness': 0.16,
#   'valence': 0.226,
#   'tempo': 121.986,
#   'time_signature': 4},
#  '46zeAK3nRlfjRmHf22lpQc': {'danceability': 0.683,
#   'energy': 0.875,
#   'key': 2,
#   'loudness': -4.804,
#   'mode': 0,
#   'speechiness': 0.052,
#   'acousticness': 0.118,
#   'instrumentalness': 0.000963,
#   'liveness': 0.0767,
#   'valence': 0.54,
#   'tempo': 120.032,
#   'time_signature': 4},
#  '1x59YtDtw7jPZTxqNYmhq2': {'danceability': 0.558,
#   'energy': 0.753,
#   'key': 5,
#   'loudness': -4.584,
#   'mode': 0,
#   'speechiness': 0.0389,
#   'acousticness': 0.000407,
#   'instrumentalness': 0.111,
#   'liveness': 0.0837,
#   'valence': 0.098,
#   'tempo': 127.979,
#   'time_signature': 4},
#  '12mGwph2YzDIlChtq3EdXP': {'danceability': 0.636,
#   'energy': 0.953,
#   'key': 2,
#   'loudness': -3.74,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.0244,
#   'instrumentalness': 0.0164,
#   'liveness': 0.108,
#   'valence': 0.397,
#   'tempo': 142.011,
#   'time_signature': 4},
#  '7IPCUIHT37O1mbk4R9O6En': {'danceability': 0.692,
#   'energy': 0.852,
#   'key': 10,
#   'loudness': -2.691,
#   'mode': 1,
#   'speechiness': 0.0287,
#   'acousticness': 0.0647,
#   'instrumentalness': 3.32e-05,
#   'liveness': 0.251,
#   'valence': 0.347,
#   'tempo': 110.0,
#   'time_signature': 4},
#  '51O58Axxs6CFiJzf1uUflq': {'danceability': 0.568,
#   'energy': 0.531,
#   'key': 5,
#   'loudness': -5.753,
#   'mode': 0,
#   'speechiness': 0.042,
#   'acousticness': 0.548,
#   'instrumentalness': 0.0022,
#   'liveness': 0.0892,
#   'valence': 0.274,
#   'tempo': 173.902,
#   'time_signature': 4},
#  '204PudWeSLHxVwOkune8mr': {'danceability': 0.428,
#   'energy': 0.848,
#   'key': 7,
#   'loudness': -3.661,
#   'mode': 0,
#   'speechiness': 0.251,
#   'acousticness': 0.0241,
#   'instrumentalness': 0.000447,
#   'liveness': 0.168,
#   'valence': 0.0896,
#   'tempo': 127.977,
#   'time_signature': 4},
#  '7BKLCZ1jbUBVqRi2FVlTVw': {'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'time_signature': 4},
#  '0UZwcRQAk4QR09HtGRZhYC': {'danceability': 0.502,
#   'energy': 0.948,
#   'key': 6,
#   'loudness': -3.717,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.0101,
#   'instrumentalness': 4.49e-06,
#   'liveness': 0.0809,
#   'valence': 0.102,
#   'tempo': 139.979,
#   'time_signature': 4},
#  '5HOpkTTVcmZHnthgyxrIL8': {'danceability': 0.703,
#   'energy': 0.867,
#   'key': 6,
#   'loudness': -4.292,
#   'mode': 1,
#   'speechiness': 0.0453,
#   'acousticness': 0.107,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.546,
#   'tempo': 128.008,
#   'time_signature': 4},
#  '59PCsXjyZnAzDTOyC4QdZx': {'danceability': 0.503,
#   'energy': 0.618,
#   'key': 7,
#   'loudness': -6.06,
#   'mode': 0,
#   'speechiness': 0.0299,
#   'acousticness': 0.379,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.232,
#   'tempo': 81.907,
#   'time_signature': 4},
#  '6tO70xUCWTTjH73QHMAvb9': {'danceability': 0.781,
#   'energy': 0.489,
#   'key': 6,
#   'loudness': -7.488,
#   'mode': 1,
#   'speechiness': 0.131,
#   'acousticness': 0.596,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.535,
#   'tempo': 120.027,
#   'time_signature': 4},
#  '4KX39APEOO2EgiZFkcJOfR': {'danceability': 0.509,
#   'energy': 0.729,
#   'key': 1,
#   'loudness': -4.773,
#   'mode': 1,
#   'speechiness': 0.0343,
#   'acousticness': 0.0732,
#   'instrumentalness': 2.73e-05,
#   'liveness': 0.233,
#   'valence': 0.196,
#   'tempo': 127.871,
#   'time_signature': 4},
#  '5MFzQMkrl1FOOng9tq6R9r': {'danceability': 0.783,
#   'energy': 0.623,
#   'key': 7,
#   'loudness': -6.126,
#   'mode': 1,
#   'speechiness': 0.08,
#   'acousticness': 0.338,
#   'instrumentalness': 0,
#   'liveness': 0.0975,
#   'valence': 0.447,
#   'tempo': 100.048,
#   'time_signature': 4},
#  '5Fm1OwRebHb5GFwdT3ia89': {'danceability': 0.55,
#   'energy': 0.686,
#   'key': 11,
#   'loudness': -4.919,
#   'mode': 0,
#   'speechiness': 0.0941,
#   'acousticness': 0.129,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.368,
#   'tempo': 148.234,
#   'time_signature': 4},
#  '1oR7VE2YJv3kT5XIa0MGMS': {'danceability': 0.465,
#   'energy': 0.406,
#   'key': 2,
#   'loudness': -6.182,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.756,
#   'instrumentalness': 0,
#   'liveness': 0.254,
#   'valence': 0.582,
#   'tempo': 94.555,
#   'time_signature': 4},
#  '0urpBLpcm6DOGzs86rcKd8': {'danceability': 0.477,
#   'energy': 0.493,
#   'key': 9,
#   'loudness': -7.346,
#   'mode': 1,
#   'speechiness': 0.0291,
#   'acousticness': 0.552,
#   'instrumentalness': 0.00345,
#   'liveness': 0.102,
#   'valence': 0.463,
#   'tempo': 148.984,
#   'time_signature': 4},
#  '4NrgHwCBgIQfst4NT2CmM3': {'danceability': 0.281,
#   'energy': 0.388,
#   'key': 0,
#   'loudness': -10.593,
#   'mode': 1,
#   'speechiness': 0.0331,
#   'acousticness': 0.396,
#   'instrumentalness': 7.81e-05,
#   'liveness': 0.144,
#   'valence': 0.259,
#   'tempo': 74.426,
#   'time_signature': 4},
#  '11m2Qis3Q4uX3pBKjYefAc': {'danceability': 0.424,
#   'energy': 0.392,
#   'key': 4,
#   'loudness': -10.35,
#   'mode': 1,
#   'speechiness': 0.0513,
#   'acousticness': 0.645,
#   'instrumentalness': 5.43e-05,
#   'liveness': 0.0675,
#   'valence': 0.38,
#   'tempo': 185.671,
#   'time_signature': 4},
#  '7wIkCYvFL159wjEDRn4qWI': {'danceability': 0.773,
#   'energy': 0.715,
#   'key': 10,
#   'loudness': -9.047,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'acousticness': 0.166,
#   'instrumentalness': 0,
#   'liveness': 0.496,
#   'valence': 0.962,
#   'tempo': 92.441,
#   'time_signature': 4},
#  '4yNoaxUJjnP50AXYoAZx4S': {'danceability': 0.335,
#   'energy': 0.865,
#   'key': 11,
#   'loudness': -4.672,
#   'mode': 0,
#   'speechiness': 0.0944,
#   'acousticness': 0.0027,
#   'instrumentalness': 0.276,
#   'liveness': 0.107,
#   'valence': 0.411,
#   'tempo': 149.85,
#   'time_signature': 4},
#  '271feX4Fipo7wGlxTYqjQa': {'danceability': 0.465,
#   'energy': 0.857,
#   'key': 2,
#   'loudness': -3.914,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.00678,
#   'instrumentalness': 1.04e-05,
#   'liveness': 0.126,
#   'valence': 0.229,
#   'tempo': 139.952,
#   'time_signature': 4},
#  '5Dk2YjSwm9U2WC1nsFuwrD': {'danceability': 0.391,
#   'energy': 0.957,
#   'key': 7,
#   'loudness': -2.51,
#   'mode': 1,
#   'speechiness': 0.0904,
#   'acousticness': 0.00331,
#   'instrumentalness': 0.22,
#   'liveness': 0.112,
#   'valence': 0.121,
#   'tempo': 100.024,
#   'time_signature': 4},
#  '44lyaXavLM0ulSopAS1F1J': {'danceability': 0.609,
#   'energy': 0.928,
#   'key': 11,
#   'loudness': -4.149,
#   'mode': 0,
#   'speechiness': 0.189,
#   'acousticness': 0.0144,
#   'instrumentalness': 0.464,
#   'liveness': 0.776,
#   'valence': 0.158,
#   'tempo': 174.977,
#   'time_signature': 4},
#  '7i0Pa4mJTJVIMw7Vy3FFUi': {'danceability': 0.51,
#   'energy': 0.701,
#   'key': 11,
#   'loudness': -7.264,
#   'mode': 1,
#   'speechiness': 0.0947,
#   'acousticness': 0.0355,
#   'instrumentalness': 0,
#   'liveness': 0.317,
#   'valence': 0.0576,
#   'tempo': 128.005,
#   'time_signature': 4},
#  '4jyPwgbt41phI3JionKQR8': {'danceability': 0.419,
#   'energy': 0.887,
#   'key': 7,
#   'loudness': -3.715,
#   'mode': 1,
#   'speechiness': 0.152,
#   'acousticness': 0.00574,
#   'instrumentalness': 0.00243,
#   'liveness': 0.165,
#   'valence': 0.132,
#   'tempo': 174.628,
#   'time_signature': 4},
#  '5ck7Ye06LHgGhWYJiAps2Q': {'danceability': 0.529,
#   'energy': 0.992,
#   'key': 5,
#   'loudness': -2.778,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.00188,
#   'instrumentalness': 0.919,
#   'liveness': 0.137,
#   'valence': 0.186,
#   'tempo': 160.013,
#   'time_signature': 4},
#  '0ng4EHlOtKCQfpJjH5djmB': {'danceability': 0.701,
#   'energy': 0.7,
#   'key': 5,
#   'loudness': -7.075,
#   'mode': 1,
#   'speechiness': 0.374,
#   'acousticness': 0.0226,
#   'instrumentalness': 0.015,
#   'liveness': 0.175,
#   'valence': 0.456,
#   'tempo': 118.002,
#   'time_signature': 4},
#  '6l8YTdyBFxP4m7fGNaUl58': {'danceability': 0.559,
#   'energy': 0.856,
#   'key': 0,
#   'loudness': -5.093,
#   'mode': 0,
#   'speechiness': 0.0971,
#   'acousticness': 0.000668,
#   'instrumentalness': 1.34e-05,
#   'liveness': 0.466,
#   'valence': 0.438,
#   'tempo': 128.003,
#   'time_signature': 4},
#  '6lHjGJAIrTWVqWn1NAiYlG': {'danceability': 0.85,
#   'energy': 0.552,
#   'key': 2,
#   'loudness': -9.438,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.00104,
#   'instrumentalness': 0.818,
#   'liveness': 0.0618,
#   'valence': 0.672,
#   'tempo': 131.014,
#   'time_signature': 4},
#  '5bX55UxmDPHnNDnee3Nhkx': {'danceability': 0.532,
#   'energy': 0.32,
#   'key': 9,
#   'loudness': -11.229,
#   'mode': 1,
#   'speechiness': 0.17,
#   'acousticness': 0.375,
#   'instrumentalness': 0.00146,
#   'liveness': 0.366,
#   'valence': 0.161,
#   'tempo': 140.07,
#   'time_signature': 4},
#  '6cxzIx8KTDEhCfGH9TAcDT': {'danceability': 0.85,
#   'energy': 0.825,
#   'key': 1,
#   'loudness': -8.284,
#   'mode': 1,
#   'speechiness': 0.106,
#   'acousticness': 0.0039,
#   'instrumentalness': 0.886,
#   'liveness': 0.109,
#   'valence': 0.815,
#   'tempo': 107.986,
#   'time_signature': 4},
#  '6KzHQR35nTZ336ABF9IiuQ': {'danceability': 0.528,
#   'energy': 0.652,
#   'key': 4,
#   'loudness': -6.776,
#   'mode': 0,
#   'speechiness': 0.0447,
#   'acousticness': 0.0052,
#   'instrumentalness': 0.815,
#   'liveness': 0.157,
#   'valence': 0.0395,
#   'tempo': 189.967,
#   'time_signature': 4},
#  '52oaUia8TvAcPvAeLL1M5F': {'danceability': 0.568,
#   'energy': 0.886,
#   'key': 2,
#   'loudness': -4.795,
#   'mode': 0,
#   'speechiness': 0.0522,
#   'acousticness': 0.0453,
#   'instrumentalness': 0.00117,
#   'liveness': 0.357,
#   'valence': 0.167,
#   'tempo': 129.034,
#   'time_signature': 4},
#  '2TNmy12Kv86t5Wt0LMDfIT': {'danceability': 0.603,
#   'energy': 0.721,
#   'key': 0,
#   'loudness': -3.843,
#   'mode': 1,
#   'speechiness': 0.0496,
#   'acousticness': 0.472,
#   'instrumentalness': 0,
#   'liveness': 0.0825,
#   'valence': 0.155,
#   'tempo': 96.899,
#   'time_signature': 4},
#  '34dkIFtyGlcg4qN0X9NBO3': {'danceability': 0.633,
#   'energy': 0.642,
#   'key': 1,
#   'loudness': -6.426,
#   'mode': 1,
#   'speechiness': 0.349,
#   'acousticness': 0.0074,
#   'instrumentalness': 0.0467,
#   'liveness': 0.313,
#   'valence': 0.613,
#   'tempo': 127.991,
#   'time_signature': 4},
#  '3s4gfqgL8GW4sKD6HCbTCO': {'danceability': 0.64,
#   'energy': 0.935,
#   'key': 1,
#   'loudness': -2.087,
#   'mode': 1,
#   'speechiness': 0.0813,
#   'acousticness': 0.00041,
#   'instrumentalness': 0.00835,
#   'liveness': 0.096,
#   'valence': 0.266,
#   'tempo': 110.07,
#   'time_signature': 4},
#  '4mdKjIVwZn8r0CdxfdeLRg': {'danceability': 0.356,
#   'energy': 0.766,
#   'key': 0,
#   'loudness': -5.008,
#   'mode': 0,
#   'speechiness': 0.0772,
#   'acousticness': 0.0233,
#   'instrumentalness': 8.44e-05,
#   'liveness': 0.115,
#   'valence': 0.371,
#   'tempo': 106.777,
#   'time_signature': 5},
#  '57JB8Nk90z6NHT9OCB5RTi': {'danceability': 0.573,
#   'energy': 0.975,
#   'key': 1,
#   'loudness': -4.717,
#   'mode': 0,
#   'speechiness': 0.0563,
#   'acousticness': 0.000102,
#   'instrumentalness': 0.193,
#   'liveness': 0.329,
#   'valence': 0.199,
#   'tempo': 130.003,
#   'time_signature': 4},
#  '6CLuXOJNHuLVAbhUP5XWFM': {'danceability': 0.546,
#   'energy': 0.804,
#   'key': 1,
#   'loudness': -2.312,
#   'mode': 1,
#   'speechiness': 0.11,
#   'acousticness': 0.00183,
#   'instrumentalness': 0.0992,
#   'liveness': 0.0705,
#   'valence': 0.36,
#   'tempo': 174.149,
#   'time_signature': 4},
#  '5Bi7zxA9t47MkTzMr5rYvZ': {'danceability': 0.787,
#   'energy': 0.75,
#   'key': 7,
#   'loudness': -6.799,
#   'mode': 1,
#   'speechiness': 0.509,
#   'acousticness': 0.549,
#   'instrumentalness': 0,
#   'liveness': 0.16,
#   'valence': 0.333,
#   'tempo': 141.003,
#   'time_signature': 4},
#  '3GUCa7VYKUcwTr5VWIkXg9': {'danceability': 0.417,
#   'energy': 0.765,
#   'key': 4,
#   'loudness': -8.747,
#   'mode': 1,
#   'speechiness': 0.157,
#   'acousticness': 0.28,
#   'instrumentalness': 1.75e-06,
#   'liveness': 0.722,
#   'valence': 0.573,
#   'tempo': 179.664,
#   'time_signature': 4},
#  '12f77tAz7FPaFxnFABoZbH': {'danceability': 0.494,
#   'energy': 0.596,
#   'key': 10,
#   'loudness': -6.95,
#   'mode': 0,
#   'speechiness': 0.612,
#   'acousticness': 0.0228,
#   'instrumentalness': 0.266,
#   'liveness': 0.107,
#   'valence': 0.152,
#   'tempo': 149.993,
#   'time_signature': 4},
#  '5fSS1HoqUnDitEc7IYSBTd': {'danceability': 0.818,
#   'energy': 0.56,
#   'key': 9,
#   'loudness': -6.799,
#   'mode': 0,
#   'speechiness': 0.0268,
#   'acousticness': 0.213,
#   'instrumentalness': 0.245,
#   'liveness': 0.0754,
#   'valence': 0.21,
#   'tempo': 124.006,
#   'time_signature': 4},
#  '718lC48FqA6liN6xSgBUhm': {'danceability': 0.705,
#   'energy': 0.924,
#   'key': 9,
#   'loudness': -2.975,
#   'mode': 0,
#   'speechiness': 0.0438,
#   'acousticness': 0.0468,
#   'instrumentalness': 0.0466,
#   'liveness': 0.573,
#   'valence': 0.307,
#   'tempo': 128.066,
#   'time_signature': 4},
#  '6YjA9S9LK1hrUFdbwz453x': {'danceability': 0.534,
#   'energy': 0.763,
#   'key': 7,
#   'loudness': -7.132,
#   'mode': 0,
#   'speechiness': 0.0826,
#   'acousticness': 0.000389,
#   'instrumentalness': 0.846,
#   'liveness': 0.0966,
#   'valence': 0.0387,
#   'tempo': 125.968,
#   'time_signature': 4},
#  '4XFMaZTEmNvsmKeQUxCfQ4': {'danceability': 0.504,
#   'energy': 0.876,
#   'key': 1,
#   'loudness': -2.992,
#   'mode': 0,
#   'speechiness': 0.062,
#   'acousticness': 0.26,
#   'instrumentalness': 0,
#   'liveness': 0.38,
#   'valence': 0.17,
#   'tempo': 109.918,
#   'time_signature': 4},
#  '0nX4hydaOORRDqlfZfJA07': {'danceability': 0.865,
#   'energy': 0.5,
#   'key': 3,
#   'loudness': -10.098,
#   'mode': 0,
#   'speechiness': 0.311,
#   'acousticness': 0.0265,
#   'instrumentalness': 0.0612,
#   'liveness': 0.36,
#   'valence': 0.617,
#   'tempo': 123.088,
#   'time_signature': 4},
#  '5IJbTPhcj0IjdzUaYqwe2I': {'danceability': 0.827,
#   'energy': 0.524,
#   'key': 10,
#   'loudness': -9.819,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.552,
#   'instrumentalness': 0.000112,
#   'liveness': 0.198,
#   'valence': 0.356,
#   'tempo': 136.785,
#   'time_signature': 4},
#  '3JaKlOxGyK5S38uI2YabYn': {'danceability': 0.785,
#   'energy': 0.504,
#   'key': 2,
#   'loudness': -8.423,
#   'mode': 1,
#   'speechiness': 0.133,
#   'acousticness': 0.175,
#   'instrumentalness': 0,
#   'liveness': 0.047,
#   'valence': 0.709,
#   'tempo': 99.464,
#   'time_signature': 4},
#  '4l1NjfkuYjoSbYjrMB6z2T': {'danceability': 0.509,
#   'energy': 0.886,
#   'key': 6,
#   'loudness': -5.589,
#   'mode': 1,
#   'speechiness': 0.0575,
#   'acousticness': 0.00258,
#   'instrumentalness': 0.756,
#   'liveness': 0.103,
#   'valence': 0.575,
#   'tempo': 139.989,
#   'time_signature': 4},
#  '5fA5LqjhNlAk3iwwSldHAy': {'danceability': 0.565,
#   'energy': 0.621,
#   'key': 10,
#   'loudness': -6.843,
#   'mode': 1,
#   'speechiness': 0.0749,
#   'acousticness': 0.67,
#   'instrumentalness': 0,
#   'liveness': 0.331,
#   'valence': 0.577,
#   'tempo': 163.998,
#   'time_signature': 4},
#  '6fkjRwfYTWdzjW6HzWIlPX': {'danceability': 0.751,
#   'energy': 0.678,
#   'key': 11,
#   'loudness': -8.424,
#   'mode': 0,
#   'speechiness': 0.0373,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.0721,
#   'valence': 0.865,
#   'tempo': 121.946,
#   'time_signature': 4},
#  '3WyawnjePexe2eqMKauJBR': {'danceability': 0.732,
#   'energy': 0.991,
#   'key': 0,
#   'loudness': -3.783,
#   'mode': 1,
#   'speechiness': 0.152,
#   'acousticness': 0.0152,
#   'instrumentalness': 0.855,
#   'liveness': 0.243,
#   'valence': 0.55,
#   'tempo': 127.015,
#   'time_signature': 4},
#  '5zOz2xrNP1x6Znpe9PaDCd': {'danceability': 0.607,
#   'energy': 0.611,
#   'key': 11,
#   'loudness': -5.627,
#   'mode': 0,
#   'speechiness': 0.161,
#   'acousticness': 0.567,
#   'instrumentalness': 1.25e-05,
#   'liveness': 0.0794,
#   'valence': 0.433,
#   'tempo': 170.079,
#   'time_signature': 4},
#  '71SZ2WDbxKnDEq1vVVj2Je': {'danceability': 0.386,
#   'energy': 0.908,
#   'key': 2,
#   'loudness': -4.215,
#   'mode': 0,
#   'speechiness': 0.143,
#   'acousticness': 0.00358,
#   'instrumentalness': 0.186,
#   'liveness': 0.308,
#   'valence': 0.622,
#   'tempo': 160.081,
#   'time_signature': 4},
#  '0SxZpiF1BfbLiKJAamelYz': {'danceability': 0.359,
#   'energy': 0.722,
#   'key': 7,
#   'loudness': -4.486,
#   'mode': 1,
#   'speechiness': 0.0383,
#   'acousticness': 0.0232,
#   'instrumentalness': 0.00109,
#   'liveness': 0.103,
#   'valence': 0.475,
#   'tempo': 96.419,
#   'time_signature': 3},
#  '6kQ9Os7x5LJ2jLHb8VWKaa': {'danceability': 0.462,
#   'energy': 0.85,
#   'key': 6,
#   'loudness': -5.558,
#   'mode': 0,
#   'speechiness': 0.0453,
#   'acousticness': 0.0256,
#   'instrumentalness': 1.94e-05,
#   'liveness': 0.0756,
#   'valence': 0.206,
#   'tempo': 172.063,
#   'time_signature': 4},
#  '3oshLPqyQEEWBCktWl8jfS': {'danceability': 0.873,
#   'energy': 0.276,
#   'key': 7,
#   'loudness': -17.043,
#   'mode': 0,
#   'speechiness': 0.588,
#   'acousticness': 0.154,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.347,
#   'tempo': 130.797,
#   'time_signature': 4},
#  '01LSU6meTykNfXu66aBTvZ': {'danceability': 0.797,
#   'energy': 0.53,
#   'key': 8,
#   'loudness': -3.802,
#   'mode': 1,
#   'speechiness': 0.0737,
#   'acousticness': 0.375,
#   'instrumentalness': 0.0048,
#   'liveness': 0.0955,
#   'valence': 0.269,
#   'tempo': 110.08,
#   'time_signature': 3},
#  '7rE9wYXPgLqZsXVxn2JhU9': {'danceability': 0.589,
#   'energy': 0.745,
#   'key': 2,
#   'loudness': -7.883,
#   'mode': 1,
#   'speechiness': 0.41,
#   'acousticness': 0.248,
#   'instrumentalness': 0,
#   'liveness': 0.246,
#   'valence': 0.328,
#   'tempo': 131.22,
#   'time_signature': 5},
#  '7qiZfU4dY1lWllzX7mPBI3': {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'time_signature': 4},
#  '0afhq8XCExXpqazXczTSve': {'danceability': 0.624,
#   'energy': 0.876,
#   'key': 9,
#   'loudness': -3.374,
#   'mode': 1,
#   'speechiness': 0.1,
#   'acousticness': 0.0735,
#   'instrumentalness': 0,
#   'liveness': 0.327,
#   'valence': 0.781,
#   'tempo': 99.943,
#   'time_signature': 4},
#  '3eR23VReFzcdmS7TYCrhCe': {'danceability': 0.64,
#   'energy': 0.533,
#   'key': 0,
#   'loudness': -6.596,
#   'mode': 1,
#   'speechiness': 0.0706,
#   'acousticness': 0.119,
#   'instrumentalness': 0,
#   'liveness': 0.0864,
#   'valence': 0.515,
#   'tempo': 99.968,
#   'time_signature': 4},
#  '0PyWKgNmGiYTFe6MXN5U4K': {'danceability': 0.684,
#   'energy': 0.549,
#   'key': 9,
#   'loudness': -5.695,
#   'mode': 1,
#   'speechiness': 0.248,
#   'acousticness': 0.11,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.277,
#   'tempo': 81.441,
#   'time_signature': 4},
#  '2pJZ1v8HezrAoZ0Fhzby92': {'danceability': 0.838,
#   'energy': 0.492,
#   'key': 1,
#   'loudness': -5.69,
#   'mode': 0,
#   'speechiness': 0.038,
#   'acousticness': 0.251,
#   'instrumentalness': 0,
#   'liveness': 0.262,
#   'valence': 0.895,
#   'tempo': 115.092,
#   'time_signature': 4},
#  '6syOdAs4IK8kPWR7gDyjRw': {'danceability': 0.629,
#   'energy': 0.817,
#   'key': 6,
#   'loudness': -4.261,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.199,
#   'instrumentalness': 0,
#   'liveness': 0.317,
#   'valence': 0.466,
#   'tempo': 123.087,
#   'time_signature': 4},
#  '0KKkJNfGyhkQ5aFogxQAPU': {'danceability': 0.853,
#   'energy': 0.56,
#   'key': 1,
#   'loudness': -4.961,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.013,
#   'instrumentalness': 0,
#   'liveness': 0.0944,
#   'valence': 0.86,
#   'tempo': 134.066,
#   'time_signature': 4},
#  '1yNyoWWWikbLhwIGWjZuDW': {'danceability': 0.563,
#   'energy': 0.775,
#   'key': 8,
#   'loudness': -6.433,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'acousticness': 0.00251,
#   'instrumentalness': 0,
#   'liveness': 0.326,
#   'valence': 0.458,
#   'tempo': 144.945,
#   'time_signature': 4},
#  '14uKsvPJ0quzQvdB6f7Dur': {'danceability': 0.67,
#   'energy': 0.839,
#   'key': 0,
#   'loudness': -4.023,
#   'mode': 1,
#   'speechiness': 0.036,
#   'acousticness': 0.0607,
#   'instrumentalness': 0.000764,
#   'liveness': 0.159,
#   'valence': 0.726,
#   'tempo': 105.002,
#   'time_signature': 4},
#  '2EEeOnHehOozLq4aS0n6SL': {'danceability': 0.746,
#   'energy': 0.653,
#   'key': 7,
#   'loudness': -6.745,
#   'mode': 1,
#   'speechiness': 0.289,
#   'acousticness': 0.378,
#   'instrumentalness': 0,
#   'liveness': 0.229,
#   'valence': 0.672,
#   'tempo': 75.016,
#   'time_signature': 4},
#  '5aAx2yezTd8zXrkmtKl66Z': {'danceability': 0.681,
#   'energy': 0.594,
#   'key': 7,
#   'loudness': -7.028,
#   'mode': 1,
#   'speechiness': 0.282,
#   'acousticness': 0.165,
#   'instrumentalness': 3.49e-06,
#   'liveness': 0.134,
#   'valence': 0.535,
#   'tempo': 186.054,
#   'time_signature': 4},
#  '15vzANxN8G9wWfwAJLLMCg': {'danceability': 0.646,
#   'energy': 0.644,
#   'key': 2,
#   'loudness': -6.763,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.0243,
#   'instrumentalness': 0,
#   'liveness': 0.0888,
#   'valence': 0.251,
#   'tempo': 99.999,
#   'time_signature': 4},
#  '3Lfiu5sZ4M4B6JaKMBc0FU': {'danceability': 0.747,
#   'energy': 0.76,
#   'key': 1,
#   'loudness': -4.294,
#   'mode': 1,
#   'speechiness': 0.187,
#   'acousticness': 0.448,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.682,
#   'tempo': 99.975,
#   'time_signature': 4},
#  '5uCax9HTNlzGybIStD3vDh': {'danceability': 0.358,
#   'energy': 0.557,
#   'key': 10,
#   'loudness': -7.398,
#   'mode': 1,
#   'speechiness': 0.059,
#   'acousticness': 0.695,
#   'instrumentalness': 0,
#   'liveness': 0.0902,
#   'valence': 0.494,
#   'tempo': 85.043,
#   'time_signature': 4},
#  '1CnPYaKxTVb4LWOtiGOm0m': {'danceability': 0.617,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -4.188,
#   'mode': 1,
#   'speechiness': 0.0828,
#   'acousticness': 0.0584,
#   'instrumentalness': 0,
#   'liveness': 0.0933,
#   'valence': 0.505,
#   'tempo': 90.246,
#   'time_signature': 4},
#  '51ChrwmUPDJvedPQnIU8Ls': {'danceability': 0.761,
#   'energy': 0.386,
#   'key': 4,
#   'loudness': -6.158,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.355,
#   'instrumentalness': 0,
#   'liveness': 0.0953,
#   'valence': 0.526,
#   'tempo': 134.943,
#   'time_signature': 3},
#  '3rOSwuTsUlJp0Pu0MkN8r8': {'danceability': 0.833,
#   'energy': 0.434,
#   'key': 2,
#   'loudness': -8.795,
#   'mode': 1,
#   'speechiness': 0.431,
#   'acousticness': 0.0102,
#   'instrumentalness': 0.0219,
#   'liveness': 0.165,
#   'valence': 0.281,
#   'tempo': 150.062,
#   'time_signature': 4},
#  '3TJk0aoXM0knrOlgd1fnbx': {'danceability': 0.675,
#   'energy': 0.632,
#   'key': 5,
#   'loudness': -4.542,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.704,
#   'tempo': 124.035,
#   'time_signature': 4},
#  '35QZaWQRkmnAVqBF1TLCxQ': {'danceability': 0.68,
#   'energy': 0.852,
#   'key': 7,
#   'loudness': -4.35,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.117,
#   'instrumentalness': 0,
#   'liveness': 0.0866,
#   'valence': 0.858,
#   'tempo': 101.993,
#   'time_signature': 4},
#  '6PCUP3dWmTjcTtXY02oFdT': {'danceability': 0.461,
#   'energy': 0.834,
#   'key': 2,
#   'loudness': -4.868,
#   'mode': 1,
#   'speechiness': 0.0989,
#   'acousticness': 0.0232,
#   'instrumentalness': 1.14e-05,
#   'liveness': 0.14,
#   'valence': 0.471,
#   'tempo': 135.007,
#   'time_signature': 4},
#  '7oolFzHipTMg2nL7shhdz2': {'danceability': 0.64,
#   'energy': 0.812,
#   'key': 8,
#   'loudness': -5.647,
#   'mode': 0,
#   'speechiness': 0.0834,
#   'acousticness': 0.086,
#   'instrumentalness': 0,
#   'liveness': 0.0509,
#   'valence': 0.914,
#   'tempo': 86.013,
#   'time_signature': 4},
#  '1dNIEtp7AY3oDAKCGg2XkH': {'danceability': 0.607,
#   'energy': 0.649,
#   'key': 11,
#   'loudness': -6.695,
#   'mode': 0,
#   'speechiness': 0.0362,
#   'acousticness': 0.0306,
#   'instrumentalness': 2.46e-05,
#   'liveness': 0.174,
#   'valence': 0.505,
#   'tempo': 102.996,
#   'time_signature': 4},
#  '3ebXMykcMXOcLeJ9xZ17XH': {'danceability': 0.584,
#   'energy': 0.54,
#   'key': 1,
#   'loudness': -7.786,
#   'mode': 0,
#   'speechiness': 0.0576,
#   'acousticness': 0.0895,
#   'instrumentalness': 0,
#   'liveness': 0.261,
#   'valence': 0.195,
#   'tempo': 137.972,
#   'time_signature': 4},
#  '5knuzwU65gJK7IF5yJsuaW': {'danceability': 0.72,
#   'energy': 0.763,
#   'key': 9,
#   'loudness': -4.068,
#   'mode': 0,
#   'speechiness': 0.0523,
#   'acousticness': 0.406,
#   'instrumentalness': 0,
#   'liveness': 0.18,
#   'valence': 0.742,
#   'tempo': 101.965,
#   'time_signature': 4},
#  '6PJ8FF6UR8FZXfEvpHkIVN': {'danceability': 0.617,
#   'energy': 0.439,
#   'key': 9,
#   'loudness': -5.63,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.424,
#   'instrumentalness': 0,
#   'liveness': 0.127,
#   'valence': 0.242,
#   'tempo': 139.979,
#   'time_signature': 4},
#  '6gpcs5eMhJwax4mIfKDYQk': {'danceability': 0.736,
#   'energy': 0.795,
#   'key': 1,
#   'loudness': -3.299,
#   'mode': 0,
#   'speechiness': 0.0545,
#   'acousticness': 0.498,
#   'instrumentalness': 1.21e-06,
#   'liveness': 0.254,
#   'valence': 0.511,
#   'tempo': 104.066,
#   'time_signature': 4},
#  '5ndfVSDyPq90jaIUhNPeby': {'danceability': 0.446,
#   'energy': 0.793,
#   'key': 0,
#   'loudness': -5.365,
#   'mode': 1,
#   'speechiness': 0.156,
#   'acousticness': 0.089,
#   'instrumentalness': 0,
#   'liveness': 0.211,
#   'valence': 0.47,
#   'tempo': 189.891,
#   'time_signature': 4},
#  '2SZy40PLDk3vFucXUGFCFA': {'danceability': 0.874,
#   'energy': 0.67,
#   'key': 11,
#   'loudness': -6.064,
#   'mode': 0,
#   'speechiness': 0.126,
#   'acousticness': 0.165,
#   'instrumentalness': 0,
#   'liveness': 0.185,
#   'valence': 0.68,
#   'tempo': 124.011,
#   'time_signature': 4},
#  '6VRghJeP6I0w1KxkdWFfIh': {'danceability': 0.77,
#   'energy': 0.787,
#   'key': 10,
#   'loudness': -4.402,
#   'mode': 0,
#   'speechiness': 0.113,
#   'acousticness': 0.0482,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.699,
#   'tempo': 125.013,
#   'time_signature': 4},
#  '5HDPtsnyb3maFmPL8LLUTG': {'danceability': 0.78,
#   'energy': 0.745,
#   'key': 7,
#   'loudness': -3.97,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.0559,
#   'instrumentalness': 0,
#   'liveness': 0.0595,
#   'valence': 0.862,
#   'tempo': 94.026,
#   'time_signature': 4},
#  '0dA2Mk56wEzDgegdC6R17g': {'danceability': 0.679,
#   'energy': 0.634,
#   'key': 5,
#   'loudness': -5.024,
#   'mode': 0,
#   'speechiness': 0.0654,
#   'acousticness': 0.232,
#   'instrumentalness': 0,
#   'liveness': 0.115,
#   'valence': 0.498,
#   'tempo': 102.013,
#   'time_signature': 4},
#  '4RepvCWqsP6zBuzvwYibAS': {'danceability': 0.769,
#   'energy': 0.813,
#   'key': 0,
#   'loudness': -5.9,
#   'mode': 0,
#   'speechiness': 0.143,
#   'acousticness': 0.429,
#   'instrumentalness': 0,
#   'liveness': 0.0952,
#   'valence': 0.567,
#   'tempo': 92.985,
#   'time_signature': 4},
#  '0tgVpDi06FyKpA1z0VMD4v': {'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'time_signature': 3},
#  '2dfHh7ECGxfNqZTQno09Vk': {'danceability': 0.604,
#   'energy': 0.366,
#   'key': 7,
#   'loudness': -7.881,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.719,
#   'instrumentalness': 0,
#   'liveness': 0.162,
#   'valence': 0.181,
#   'tempo': 105.177,
#   'time_signature': 3},
#  '3WOUyEmV9Hi12JKn9QeLjI': {'danceability': 0.721,
#   'energy': 0.736,
#   'key': 10,
#   'loudness': -8.15,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.24,
#   'instrumentalness': 0.02,
#   'liveness': 0.0892,
#   'valence': 0.417,
#   'tempo': 127.974,
#   'time_signature': 4},
#  '2RttW7RAu5nOAfq6YFvApB': {'danceability': 0.522,
#   'energy': 0.385,
#   'key': 0,
#   'loudness': -7.355,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.536,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.236,
#   'tempo': 89.792,
#   'time_signature': 4},
#  '5Wh7OXtD7BzzUmhwzOpBZb': {'danceability': 0.803,
#   'energy': 0.743,
#   'key': 1,
#   'loudness': -3.602,
#   'mode': 0,
#   'speechiness': 0.0681,
#   'acousticness': 0.105,
#   'instrumentalness': 2.12e-06,
#   'liveness': 0.099,
#   'valence': 0.674,
#   'tempo': 108.005,
#   'time_signature': 4},
#  '6HUnnBwYZqcED1eQztxMBN': {'danceability': 0.744,
#   'energy': 0.836,
#   'key': 6,
#   'loudness': -2.396,
#   'mode': 0,
#   'speechiness': 0.0507,
#   'acousticness': 0.0435,
#   'instrumentalness': 0,
#   'liveness': 0.194,
#   'valence': 0.36,
#   'tempo': 114.965,
#   'time_signature': 4},
#  '1sXUWdKx03aP9Gmzft58rt': {'danceability': 0.683,
#   'energy': 0.427,
#   'key': 8,
#   'loudness': -6.827,
#   'mode': 1,
#   'speechiness': 0.0777,
#   'acousticness': 0.368,
#   'instrumentalness': 0,
#   'liveness': 0.0604,
#   'valence': 0.426,
#   'tempo': 113.634,
#   'time_signature': 4},
#  '4Km5HrUvYTaSUfiSGPJeQR': {'danceability': 0.926,
#   'energy': 0.666,
#   'key': 11,
#   'loudness': -5.314,
#   'mode': 1,
#   'speechiness': 0.244,
#   'acousticness': 0.0611,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.168,
#   'tempo': 127.079,
#   'time_signature': 4},
#  '1WniHvhq9zTkny0WvGXX8o': {'danceability': 0.859,
#   'energy': 0.756,
#   'key': 8,
#   'loudness': -3.36,
#   'mode': 0,
#   'speechiness': 0.0643,
#   'acousticness': 0.168,
#   'instrumentalness': 4.65e-05,
#   'liveness': 0.163,
#   'valence': 0.91,
#   'tempo': 102.033,
#   'time_signature': 4},
#  '5NNlUMcOEOdoOIwwaWXv0k': {'danceability': 0.703,
#   'energy': 0.715,
#   'key': 9,
#   'loudness': -6.285,
#   'mode': 0,
#   'speechiness': 0.114,
#   'acousticness': 0.139,
#   'instrumentalness': 0,
#   'liveness': 0.0456,
#   'valence': 0.497,
#   'tempo': 99.924,
#   'time_signature': 4},
#  '1WC5UN1U79gJlxGLYDGIO7': {'danceability': 0.61,
#   'energy': 0.712,
#   'key': 9,
#   'loudness': -7.808,
#   'mode': 1,
#   'speechiness': 0.0776,
#   'acousticness': 0.0147,
#   'instrumentalness': 1.12e-05,
#   'liveness': 0.0843,
#   'valence': 0.283,
#   'tempo': 128.921,
#   'time_signature': 4},
#  '3EmmCZoqpWOTY1g2GBwJoR': {'danceability': 0.647,
#   'energy': 0.932,
#   'key': 11,
#   'loudness': -3.515,
#   'mode': 1,
#   'speechiness': 0.0824,
#   'acousticness': 0.00383,
#   'instrumentalness': 1.5e-06,
#   'liveness': 0.0574,
#   'valence': 0.374,
#   'tempo': 114.991,
#   'time_signature': 4},
#  '7nKBxz47S9SD79N086fuhn': {'danceability': 0.688,
#   'energy': 0.822,
#   'key': 0,
#   'loudness': -3.304,
#   'mode': 1,
#   'speechiness': 0.0537,
#   'acousticness': 0.0642,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.66,
#   'tempo': 91.011,
#   'time_signature': 4},
#  '4VuS959DSpr82t3qBqCrWG': {'danceability': 0.589,
#   'energy': 0.242,
#   'key': 6,
#   'loudness': -10.517,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'acousticness': 0.914,
#   'instrumentalness': 0,
#   'liveness': 0.0887,
#   'valence': 0.257,
#   'tempo': 89.749,
#   'time_signature': 4},
#  '3umS4y3uQDkqekNjVpiRUs': {'danceability': 0.683,
#   'energy': 0.691,
#   'key': 8,
#   'loudness': -5.535,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.243,
#   'instrumentalness': 0,
#   'liveness': 0.14,
#   'valence': 0.732,
#   'tempo': 179.91,
#   'time_signature': 4},
#  '4aWmUDTfIPGksMNLV2rQP2': {'danceability': 0.66,
#   'energy': 0.786,
#   'key': 2,
#   'loudness': -4.757,
#   'mode': 1,
#   'speechiness': 0.17,
#   'acousticness': 0.209,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.846,
#   'tempo': 177.833,
#   'time_signature': 4},
#  '5yzuAVmDCCuRM5bDT9H4Y0': {'danceability': 0.404,
#   'energy': 0.667,
#   'key': 7,
#   'loudness': -5.077,
#   'mode': 1,
#   'speechiness': 0.421,
#   'acousticness': 0.0378,
#   'instrumentalness': 2.08e-05,
#   'liveness': 0.212,
#   'valence': 0.213,
#   'tempo': 166.265,
#   'time_signature': 4},
#  '5rRMux9vrgG0HAnW8AgFCt': {'danceability': 0.735,
#   'energy': 0.812,
#   'key': 1,
#   'loudness': -1.238,
#   'mode': 1,
#   'speechiness': 0.128,
#   'acousticness': 0.351,
#   'instrumentalness': 0,
#   'liveness': 0.261,
#   'valence': 0.31,
#   'tempo': 106.33,
#   'time_signature': 4},
#  '3NdDpSvN911VPGivFlV5d0': {'danceability': 0.735,
#   'energy': 0.451,
#   'key': 0,
#   'loudness': -8.374,
#   'mode': 1,
#   'speechiness': 0.0585,
#   'acousticness': 0.0631,
#   'instrumentalness': 1.3e-05,
#   'liveness': 0.325,
#   'valence': 0.0862,
#   'tempo': 117.973,
#   'time_signature': 4},
#  '043MJ8zk9VQLvXXV01UbH6': {'danceability': 0.289,
#   'energy': 0.36,
#   'key': 5,
#   'loudness': -13.008,
#   'mode': 1,
#   'speechiness': 0.0391,
#   'acousticness': 0.931,
#   'instrumentalness': 0.88,
#   'liveness': 0.265,
#   'valence': 0.366,
#   'tempo': 119.899,
#   'time_signature': 4},
#  '37Yr8hkrWzfWT7ZRsfCOzX': {'danceability': 0.552,
#   'energy': 0.964,
#   'key': 4,
#   'loudness': -4.189,
#   'mode': 1,
#   'speechiness': 0.428,
#   'acousticness': 0.55,
#   'instrumentalness': 0.000452,
#   'liveness': 0.225,
#   'valence': 0.631,
#   'tempo': 183.993,
#   'time_signature': 4},
#  '527iyT77FKfKsWb59QeetM': {'danceability': 0.0732,
#   'energy': 0.386,
#   'key': 2,
#   'loudness': -9.358,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.566,
#   'instrumentalness': 0.0857,
#   'liveness': 0.0771,
#   'valence': 0.0969,
#   'tempo': 182.427,
#   'time_signature': 3},
#  '6BwGADsK48truigixSvLps': {'danceability': 0.43,
#   'energy': 0.85,
#   'key': 2,
#   'loudness': -5.457,
#   'mode': 0,
#   'speechiness': 0.465,
#   'acousticness': 0.771,
#   'instrumentalness': 0.396,
#   'liveness': 0.0711,
#   'valence': 0.577,
#   'tempo': 174.694,
#   'time_signature': 3},
#  '3UCrsQ2v8vexY7pcsoUxo1': {'danceability': 0.443,
#   'energy': 0.42,
#   'key': 2,
#   'loudness': -12.027,
#   'mode': 0,
#   'speechiness': 0.0306,
#   'acousticness': 0.808,
#   'instrumentalness': 0.804,
#   'liveness': 0.095,
#   'valence': 0.443,
#   'tempo': 135.291,
#   'time_signature': 4},
#  '0fDXx9vVgfdLZasmDoVnqP': {'danceability': 0.356,
#   'energy': 0.184,
#   'key': 2,
#   'loudness': -12.104,
#   'mode': 0,
#   'speechiness': 0.0391,
#   'acousticness': 0.922,
#   'instrumentalness': 0.946,
#   'liveness': 0.123,
#   'valence': 0.312,
#   'tempo': 118.299,
#   'time_signature': 4},
#  '4KbrSpUpAViTkxs7e4aunN': {'danceability': 0.212,
#   'energy': 0.382,
#   'key': 0,
#   'loudness': -12.266,
#   'mode': 0,
#   'speechiness': 0.0431,
#   'acousticness': 0.962,
#   'instrumentalness': 0.792,
#   'liveness': 0.098,
#   'valence': 0.0646,
#   'tempo': 84.814,
#   'time_signature': 4},
#  '4Wqyc4zng66azPNuGp9Hp7': {'danceability': 0.136,
#   'energy': 0.159,
#   'key': 0,
#   'loudness': -15.767,
#   'mode': 0,
#   'speechiness': 0.0452,
#   'acousticness': 0.985,
#   'instrumentalness': 0.75,
#   'liveness': 0.065,
#   'valence': 0.147,
#   'tempo': 79.801,
#   'time_signature': 4},
#  '1IbqahgWSIgMcgUxbupT19': {'danceability': 0.231,
#   'energy': 0.694,
#   'key': 10,
#   'loudness': -5.235,
#   'mode': 0,
#   'speechiness': 0.0514,
#   'acousticness': 0.00443,
#   'instrumentalness': 0.068,
#   'liveness': 0.366,
#   'valence': 0.0762,
#   'tempo': 125.317,
#   'time_signature': 4},
#  '7HHIwfRPcfnvUTK2zOGrD0': {'danceability': 0.475,
#   'energy': 0.824,
#   'key': 8,
#   'loudness': -5.019,
#   'mode': 1,
#   'speechiness': 0.0622,
#   'acousticness': 0.12,
#   'instrumentalness': 0,
#   'liveness': 0.389,
#   'valence': 0.503,
#   'tempo': 143.969,
#   'time_signature': 4},
#  '2PH4A0uzqE8DSinxxETZrE': {'danceability': 0.364,
#   'energy': 0.844,
#   'key': 0,
#   'loudness': -6.442,
#   'mode': 1,
#   'speechiness': 0.0479,
#   'acousticness': 0.0571,
#   'instrumentalness': 0,
#   'liveness': 0.121,
#   'valence': 0.593,
#   'tempo': 170.114,
#   'time_signature': 4},
#  '6HH1qlyyVAAJzbctS0OYKB': {'danceability': 0.656,
#   'energy': 0.941,
#   'key': 9,
#   'loudness': -3.48,
#   'mode': 1,
#   'speechiness': 0.0435,
#   'acousticness': 0.225,
#   'instrumentalness': 0,
#   'liveness': 0.235,
#   'valence': 0.565,
#   'tempo': 123.015,
#   'time_signature': 4},
#  '2fcg8FwEs3OhcyT91mbvT4': {'danceability': 0.613,
#   'energy': 0.727,
#   'key': 2,
#   'loudness': -5.624,
#   'mode': 1,
#   'speechiness': 0.0227,
#   'acousticness': 0.277,
#   'instrumentalness': 0,
#   'liveness': 0.354,
#   'valence': 0.788,
#   'tempo': 96.01,
#   'time_signature': 4},
#  '2NMBRQiJSTuiLBCwHVTlnq': {'danceability': 0.596,
#   'energy': 0.758,
#   'key': 8,
#   'loudness': -3.717,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.00739,
#   'instrumentalness': 0,
#   'liveness': 0.0409,
#   'valence': 0.779,
#   'tempo': 114.941,
#   'time_signature': 4},
#  '4XD7dBLAbo3C5UF8N5WuD1': {'danceability': 0.655,
#   'energy': 0.669,
#   'key': 3,
#   'loudness': -4.037,
#   'mode': 1,
#   'speechiness': 0.0294,
#   'acousticness': 0.589,
#   'instrumentalness': 0,
#   'liveness': 0.0796,
#   'valence': 0.389,
#   'tempo': 117.061,
#   'time_signature': 4},
#  '0f34MnV51uwA1jhPQ2XnDe': {'danceability': 0.366,
#   'energy': 0.893,
#   'key': 5,
#   'loudness': -5.913,
#   'mode': 0,
#   'speechiness': 0.091,
#   'acousticness': 0.003,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.141,
#   'valence': 0.471,
#   'tempo': 171.064,
#   'time_signature': 4},
#  '2p7kd9XmOXxSd9Czqdl59B': {'danceability': 0.537,
#   'energy': 0.597,
#   'key': 0,
#   'loudness': -6.708,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.0341,
#   'instrumentalness': 0,
#   'liveness': 0.0812,
#   'valence': 0.34,
#   'tempo': 125.97,
#   'time_signature': 4},
#  '7nMyG8CJCgLweioZNOqRJc': {'danceability': 0.302,
#   'energy': 0.904,
#   'key': 11,
#   'loudness': -4.606,
#   'mode': 1,
#   'speechiness': 0.0563,
#   'acousticness': 0.0114,
#   'instrumentalness': 1.51e-05,
#   'liveness': 0.564,
#   'valence': 0.559,
#   'tempo': 96.002,
#   'time_signature': 3},
#  '1JdnhcPSrGF8bGzUdXw96l': {'danceability': 0.566,
#   'energy': 0.804,
#   'key': 7,
#   'loudness': -3.387,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.0247,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.608,
#   'tempo': 139.996,
#   'time_signature': 4},
#  '7hDc8b7IXETo14hHIHdnhd': {'danceability': 0.809,
#   'energy': 0.463,
#   'key': 11,
#   'loudness': -11.377,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'acousticness': 0.256,
#   'instrumentalness': 0.085,
#   'liveness': 0.109,
#   'valence': 0.364,
#   'tempo': 111.98,
#   'time_signature': 4},
#  '3GnLo84IkdSWCPYt6tnLll': {'danceability': 0.905,
#   'energy': 0.596,
#   'key': 1,
#   'loudness': -7.496,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.000339,
#   'instrumentalness': 2.05e-05,
#   'liveness': 0.0897,
#   'valence': 0.422,
#   'tempo': 149.996,
#   'time_signature': 4},
#  '1x5sYLZiu9r5E43kMlt9f8': {'danceability': 0.707,
#   'energy': 0.629,
#   'key': 0,
#   'loudness': -4.581,
#   'mode': 0,
#   'speechiness': 0.0563,
#   'acousticness': 0.259,
#   'instrumentalness': 1.6e-05,
#   'liveness': 0.138,
#   'valence': 0.457,
#   'tempo': 122.863,
#   'time_signature': 4},
#  '6Zosz8w6CmdGMZM6p4JlbQ': {'danceability': 0.746,
#   'energy': 0.794,
#   'key': 1,
#   'loudness': -6.331,
#   'mode': 1,
#   'speechiness': 0.0698,
#   'acousticness': 0.0258,
#   'instrumentalness': 0,
#   'liveness': 0.0497,
#   'valence': 0.447,
#   'tempo': 104.827,
#   'time_signature': 4},
#  '2BoS7pU92MQtynhQ0cZOLT': {'danceability': 0.497,
#   'energy': 0.489,
#   'key': 11,
#   'loudness': -7.724,
#   'mode': 0,
#   'speechiness': 0.294,
#   'acousticness': 0.0576,
#   'instrumentalness': 9.91e-05,
#   'liveness': 0.122,
#   'valence': 0.231,
#   'tempo': 171.853,
#   'time_signature': 4},
#  '2jG6ifTWXk0AvonlgcXGgZ': {'danceability': 0.925,
#   'energy': 0.443,
#   'key': 1,
#   'loudness': -8.216,
#   'mode': 1,
#   'speechiness': 0.264,
#   'acousticness': 0.0172,
#   'instrumentalness': 0,
#   'liveness': 0.276,
#   'valence': 0.35,
#   'tempo': 136.078,
#   'time_signature': 4},
#  '5hYTyyh2odQKphUbMqc5gN': {'danceability': 0.314,
#   'energy': 0.555,
#   'key': 9,
#   'loudness': -9.601,
#   'mode': 1,
#   'speechiness': 0.37,
#   'acousticness': 0.157,
#   'instrumentalness': 0.000108,
#   'liveness': 0.067,
#   'valence': 0.159,
#   'tempo': 179.666,
#   'time_signature': 4},
#  '37Hr7Cnjt9uqPpPqDnjsWo': {'danceability': 0.774,
#   'energy': 0.621,
#   'key': 10,
#   'loudness': -11.541,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.192,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.964,
#   'tempo': 92.657,
#   'time_signature': 4},
#  '3SP0MlWYfu7xt1ZfMqBxh9': {'danceability': 0.586,
#   'energy': 0.474,
#   'key': 10,
#   'loudness': -7.063,
#   'mode': 0,
#   'speechiness': 0.274,
#   'acousticness': 0.616,
#   'instrumentalness': 1.04e-05,
#   'liveness': 0.613,
#   'valence': 0.455,
#   'tempo': 149.967,
#   'time_signature': 4},
#  '5ELRkzdzz0HvGpMDlfZHkV': {'danceability': 0.518,
#   'energy': 0.575,
#   'key': 5,
#   'loudness': -4.616,
#   'mode': 1,
# ...
#   'energy': 0.651,
#   'key': 6,
#   'loudness': -8.446,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.0698,
#   'instrumentalness': 0.0835,
#   'liveness': 0.0899,
#   'valence': 0.458,
#   'tempo': 109.994,
#   'time_signature': 4},
#  '1jsuNY2norISRscbYj5ISS': {'danceability': 0.587,
#   'energy': 0.768,
#   'key': 2,
#   'loudness': -5.674,
#   'mode': 0,
#   'speechiness': 0.0346,
#   'acousticness': 0.0312,
#   'instrumentalness': 0.000224,
#   'liveness': 0.216,
#   'valence': 0.395,
#   'tempo': 127.981,
#   'time_signature': 4},
#  '5nfr8CQxhR2xKmyI5hy9sK': {'danceability': 0.732,
#   'energy': 0.574,
#   'key': 7,
#   'loudness': -7.205,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.129,
#   'instrumentalness': 0.000178,
#   'liveness': 0.105,
#   'valence': 0.552,
#   'tempo': 115.969,
#   'time_signature': 4},
#  '3xA7q8yI1Lq9GAPyzrF9yZ': {'danceability': 0.655,
#   'energy': 0.889,
#   'key': 6,
#   'loudness': -4.163,
#   'mode': 0,
#   'speechiness': 0.0372,
#   'acousticness': 0.108,
#   'instrumentalness': 0.129,
#   'liveness': 0.839,
#   'valence': 0.422,
#   'tempo': 100.02,
#   'time_signature': 4},
#  '1WfJ6JyQ3prYlxXXnVxtWz': {'danceability': 0.893,
#   'energy': 0.43,
#   'key': 0,
#   'loudness': -13.995,
#   'mode': 1,
#   'speechiness': 0.197,
#   'acousticness': 0.392,
#   'instrumentalness': 0.938,
#   'liveness': 0.152,
#   'valence': 0.305,
#   'tempo': 140.013,
#   'time_signature': 4},
#  '3ijrrM0lNOXCJBBrsVhcLZ': {'danceability': 0.637,
#   'energy': 0.455,
#   'key': 3,
#   'loudness': -10.363,
#   'mode': 1,
#   'speechiness': 0.0285,
#   'acousticness': 0.75,
#   'instrumentalness': 0.0162,
#   'liveness': 0.129,
#   'valence': 0.27,
#   'tempo': 109.968,
#   'time_signature': 4},
#  '4hbAPzoCrnmVfpswf1Nfos': {'danceability': 0.759,
#   'energy': 0.594,
#   'key': 9,
#   'loudness': -8.556,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.0401,
#   'instrumentalness': 0.000849,
#   'liveness': 0.139,
#   'valence': 0.522,
#   'tempo': 148.005,
#   'time_signature': 4},
#  '557y7PDrfoG7ZiXE82XPxp': {'danceability': 0.6,
#   'energy': 0.205,
#   'key': 1,
#   'loudness': -17.841,
#   'mode': 1,
#   'speechiness': 0.0814,
#   'acousticness': 0.893,
#   'instrumentalness': 0.891,
#   'liveness': 0.103,
#   'valence': 0.181,
#   'tempo': 124.983,
#   'time_signature': 4},
#  '3sxTrGBmfjlMJIy3QaxsTP': {'danceability': 0.409,
#   'energy': 0.262,
#   'key': 2,
#   'loudness': -15.155,
#   'mode': 0,
#   'speechiness': 0.171,
#   'acousticness': 0.17,
#   'instrumentalness': 0.212,
#   'liveness': 0.073,
#   'valence': 0.313,
#   'tempo': 160.107,
#   'time_signature': 4},
#  '0cmpaEz9k3FCpXrZeG6zE6': {'danceability': 0.779,
#   'energy': 0.637,
#   'key': 2,
#   'loudness': -5.454,
#   'mode': 1,
#   'speechiness': 0.0354,
#   'acousticness': 0.531,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.636,
#   'tempo': 122.995,
#   'time_signature': 4},
#  '2x4ZC6OpEvud8HayLpceue': {'danceability': 0.613,
#   'energy': 0.475,
#   'key': 3,
#   'loudness': -10.963,
#   'mode': 1,
#   'speechiness': 0.0285,
#   'acousticness': 0.777,
#   'instrumentalness': 0.0723,
#   'liveness': 0.079,
#   'valence': 0.327,
#   'tempo': 124.992,
#   'time_signature': 4},
#  '6j236RwzFFj4wqH2tWJNBD': {'danceability': 0.4,
#   'energy': 0.882,
#   'key': 7,
#   'loudness': -1.958,
#   'mode': 0,
#   'speechiness': 0.334,
#   'acousticness': 0.168,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.385,
#   'tempo': 167.114,
#   'time_signature': 4},
#  '1mr3616BzLdhXfJmLmRsO8': {'danceability': 0.513,
#   'energy': 0.661,
#   'key': 3,
#   'loudness': -6.8,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.0274,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.461,
#   'tempo': 180.118,
#   'time_signature': 4},
#  '7cE8VabTiFSjD2FSf6xrOx': {'danceability': 0.542,
#   'energy': 0.962,
#   'key': 1,
#   'loudness': -2.348,
#   'mode': 1,
#   'speechiness': 0.167,
#   'acousticness': 0.00283,
#   'instrumentalness': 0.0149,
#   'liveness': 0.41,
#   'valence': 0.215,
#   'tempo': 174.034,
#   'time_signature': 4},
#  '4rKTvV3QCEwhmnrxcw6PGn': {'danceability': 0.523,
#   'energy': 0.936,
#   'key': 1,
#   'loudness': -2.499,
#   'mode': 1,
#   'speechiness': 0.159,
#   'acousticness': 0.00166,
#   'instrumentalness': 0.119,
#   'liveness': 0.445,
#   'valence': 0.191,
#   'tempo': 173.996,
#   'time_signature': 4},
#  '6Rvpcw4OnG9fMfcxVIyEhL': {'danceability': 0.302,
#   'energy': 0.938,
#   'key': 2,
#   'loudness': -10.232,
#   'mode': 1,
#   'speechiness': 0.0749,
#   'acousticness': 0.451,
#   'instrumentalness': 0,
#   'liveness': 0.312,
#   'valence': 0.0883,
#   'tempo': 189.105,
#   'time_signature': 3},
#  '0vwETfTihkeOWR7ChJ7KFe': {'danceability': 0.452,
#   'energy': 0.435,
#   'key': 1,
#   'loudness': -19.218,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.783,
#   'instrumentalness': 0.92,
#   'liveness': 0.132,
#   'valence': 0.0499,
#   'tempo': 105.2,
#   'time_signature': 4},
#  '6nbVSUTp2Ucku7TXMtgiTd': {'danceability': 0.536,
#   'energy': 0.496,
#   'key': 2,
#   'loudness': -16.263,
#   'mode': 1,
#   'speechiness': 0.0608,
#   'acousticness': 0.345,
#   'instrumentalness': 0.843,
#   'liveness': 0.354,
#   'valence': 0.148,
#   'tempo': 160.1,
#   'time_signature': 4},
#  '5hQll2t2rfpVARhVjDVOYJ': {'danceability': 0.424,
#   'energy': 0.899,
#   'key': 11,
#   'loudness': -3.937,
#   'mode': 0,
#   'speechiness': 0.0572,
#   'acousticness': 0.0034,
#   'instrumentalness': 8.1e-05,
#   'liveness': 0.223,
#   'valence': 0.74,
#   'tempo': 171.832,
#   'time_signature': 4},
#  '2ofTMnXr1F24XmXCdKUfmM': {'danceability': 0.636,
#   'energy': 0.868,
#   'key': 2,
#   'loudness': -3.036,
#   'mode': 0,
#   'speechiness': 0.047,
#   'acousticness': 0.103,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.707,
#   'tempo': 129.99,
#   'time_signature': 4},
#  '26sfOdUbSSm6nnmcuXL61P': {'danceability': 0.27,
#   'energy': 0.728,
#   'key': 1,
#   'loudness': -5.196,
#   'mode': 1,
#   'speechiness': 0.052,
#   'acousticness': 0.309,
#   'instrumentalness': 0,
#   'liveness': 0.0947,
#   'valence': 0.191,
#   'tempo': 120.25,
#   'time_signature': 4},
#  '70hvCk6sUutFjKA1Y4W1mc': {'danceability': 0.592,
#   'energy': 0.693,
#   'key': 7,
#   'loudness': -4.934,
#   'mode': 0,
#   'speechiness': 0.0395,
#   'acousticness': 0.397,
#   'instrumentalness': 2.87e-05,
#   'liveness': 0.242,
#   'valence': 0.255,
#   'tempo': 120.076,
#   'time_signature': 4},
#  '2WfaOiMkCvy7F5fcp2zZ8L': {'danceability': 0.573,
#   'energy': 0.902,
#   'key': 6,
#   'loudness': -7.638,
#   'mode': 0,
#   'speechiness': 0.054,
#   'acousticness': 0.018,
#   'instrumentalness': 0.00125,
#   'liveness': 0.0928,
#   'valence': 0.876,
#   'tempo': 84.412,
#   'time_signature': 4},
#  '7CFN1zqKSjucIyDzcrqE6I': {'danceability': 0.47,
#   'energy': 0.198,
#   'key': 9,
#   'loudness': -13.308,
#   'mode': 1,
#   'speechiness': 0.0404,
#   'acousticness': 0.965,
#   'instrumentalness': 2.87e-05,
#   'liveness': 0.686,
#   'valence': 0.307,
#   'tempo': 128.988,
#   'time_signature': 4},
#  '5st5644IlBmKiiRE73UsoZ': {'danceability': 0.775,
#   'energy': 0.904,
#   'key': 1,
#   'loudness': -4.08,
#   'mode': 0,
#   'speechiness': 0.0437,
#   'acousticness': 0.0271,
#   'instrumentalness': 0.000303,
#   'liveness': 0.06,
#   'valence': 0.84,
#   'tempo': 130.009,
#   'time_signature': 4},
#  '76FnCkhueYsfbyTv5Rm65B': {'danceability': 0.662,
#   'energy': 0.624,
#   'key': 10,
#   'loudness': -7.552,
#   'mode': 1,
#   'speechiness': 0.0408,
#   'acousticness': 0.468,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.109,
#   'valence': 0.524,
#   'tempo': 83.979,
#   'time_signature': 4},
#  '6IFXwxWeLkeQ68XaUAcxUf': {'danceability': 0.541,
#   'energy': 0.925,
#   'key': 7,
#   'loudness': -6.585,
#   'mode': 0,
#   'speechiness': 0.0843,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.357,
#   'tempo': 143.011,
#   'time_signature': 4},
#  '56N9s9PS6VwGolUnx1CJkv': {'danceability': 0.313,
#   'energy': 0.286,
#   'key': 10,
#   'loudness': -10.593,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.934,
#   'instrumentalness': 0.0451,
#   'liveness': 0.0974,
#   'valence': 0.287,
#   'tempo': 80.925,
#   'time_signature': 4},
#  '79z9QkhHePTFsSeVw9uyj0': {'danceability': 0.632,
#   'energy': 0.639,
#   'key': 5,
#   'loudness': -5.938,
#   'mode': 1,
#   'speechiness': 0.0259,
#   'acousticness': 0.00143,
#   'instrumentalness': 0,
#   'liveness': 0.221,
#   'valence': 0.733,
#   'tempo': 95.506,
#   'time_signature': 4},
#  '5wD6de7Fz1QfxVNkv1SEy7': {'danceability': 0.675,
#   'energy': 0.631,
#   'key': 5,
#   'loudness': -7.56,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.0147,
#   'instrumentalness': 4.39e-06,
#   'liveness': 0.379,
#   'valence': 0.917,
#   'tempo': 100.027,
#   'time_signature': 4},
#  '1cDRpJiJa94Voj0Ayc9iGJ': {'danceability': 0.718,
#   'energy': 0.806,
#   'key': 5,
#   'loudness': -9.191,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.052,
#   'instrumentalness': 0.0137,
#   'liveness': 0.0932,
#   'valence': 0.929,
#   'tempo': 121.488,
#   'time_signature': 4},
#  '4OLVK3kktkdLPp8dDgoCtb': {'danceability': 0.522,
#   'energy': 0.53,
#   'key': 4,
#   'loudness': -4.812,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 0.294,
#   'instrumentalness': 5.19e-05,
#   'liveness': 0.0997,
#   'valence': 0.157,
#   'tempo': 104.039,
#   'time_signature': 4},
#  '58zsLZPvfflaiIbNWoA22O': {'danceability': 0.602,
#   'energy': 0.707,
#   'key': 9,
#   'loudness': -4.097,
#   'mode': 1,
#   'speechiness': 0.302,
#   'acousticness': 0.393,
#   'instrumentalness': 0,
#   'liveness': 0.165,
#   'valence': 0.554,
#   'tempo': 75.087,
#   'time_signature': 4},
#  '6UFr9KANWaH5jiB9PIPS9C': {'danceability': 0.514,
#   'energy': 0.156,
#   'key': 7,
#   'loudness': -22.516,
#   'mode': 0,
#   'speechiness': 0.0368,
#   'acousticness': 0.877,
#   'instrumentalness': 0.888,
#   'liveness': 0.0814,
#   'valence': 0.0599,
#   'tempo': 112.56,
#   'time_signature': 3},
#  '0D2m3GX6mNfNB6dKJQjCgM': {'danceability': 0.567,
#   'energy': 0.865,
#   'key': 1,
#   'loudness': -7.401,
#   'mode': 1,
#   'speechiness': 0.0289,
#   'acousticness': 0.472,
#   'instrumentalness': 0.000437,
#   'liveness': 0.0845,
#   'valence': 0.421,
#   'tempo': 110.851,
#   'time_signature': 3},
#  '7pzdiluN2tVrxsFGyM2Asc': {'danceability': 0.596,
#   'energy': 0.846,
#   'key': 9,
#   'loudness': -5.415,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0734,
#   'instrumentalness': 0,
#   'liveness': 0.248,
#   'valence': 0.317,
#   'tempo': 120.017,
#   'time_signature': 4},
#  '2ewOCJvEeaxihhUZdaucqQ': {'danceability': 0.614,
#   'energy': 0.924,
#   'key': 9,
#   'loudness': -3.388,
#   'mode': 1,
#   'speechiness': 0.0701,
#   'acousticness': 0.000837,
#   'instrumentalness': 9.94e-05,
#   'liveness': 0.0986,
#   'valence': 0.55,
#   'tempo': 115.017,
#   'time_signature': 4},
#  '7lLKxcNeJtDTWVRKHovLEC': {'danceability': 0.526,
#   'energy': 0.333,
#   'key': 4,
#   'loudness': -13.02,
#   'mode': 1,
#   'speechiness': 0.0314,
#   'acousticness': 0.91,
#   'instrumentalness': 0.168,
#   'liveness': 0.111,
#   'valence': 0.159,
#   'tempo': 94.951,
#   'time_signature': 4},
#  '3Wd3mAficthmcUcCICvwSG': {'danceability': 0.417,
#   'energy': 0.403,
#   'key': 0,
#   'loudness': -10.478,
#   'mode': 1,
#   'speechiness': 0.0291,
#   'acousticness': 0.562,
#   'instrumentalness': 0.0282,
#   'liveness': 0.113,
#   'valence': 0.169,
#   'tempo': 105.807,
#   'time_signature': 4},
#  '79cuOz3SPQTuFrp8WgftAu': {'danceability': 0.857,
#   'energy': 0.8,
#   'key': 2,
#   'loudness': -4.035,
#   'mode': 1,
#   'speechiness': 0.0583,
#   'acousticness': 0.381,
#   'instrumentalness': 0,
#   'liveness': 0.0913,
#   'valence': 0.966,
#   'tempo': 121.996,
#   'time_signature': 4},
#  '4Rwfg1x0g3cd5UwuK2UVLa': {'danceability': 0.334,
#   'energy': 0.427,
#   'key': 2,
#   'loudness': -6.681,
#   'mode': 1,
#   'speechiness': 0.0341,
#   'acousticness': 0.242,
#   'instrumentalness': 0,
#   'liveness': 0.072,
#   'valence': 0.34,
#   'tempo': 169.366,
#   'time_signature': 4},
#  '2eha6iitIJ7EaVdvusgtQi': {'danceability': 0.649,
#   'energy': 0.548,
#   'key': 1,
#   'loudness': -6.879,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.0182,
#   'instrumentalness': 0,
#   'liveness': 0.165,
#   'valence': 0.075,
#   'tempo': 76.008,
#   'time_signature': 4},
#  '1UQKGA5ZSetcDjdW3IMWnY': {'danceability': 0.527,
#   'energy': 0.259,
#   'key': 0,
#   'loudness': -11.436,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.965,
#   'instrumentalness': 0.879,
#   'liveness': 0.151,
#   'valence': 0.205,
#   'tempo': 119.975,
#   'time_signature': 4},
#  '4I18rXWixQBWc8JhTqx6Xn': {'danceability': 0.495,
#   'energy': 0.329,
#   'key': 7,
#   'loudness': -11.661,
#   'mode': 1,
#   'speechiness': 0.0386,
#   'acousticness': 0.652,
#   'instrumentalness': 7.61e-05,
#   'liveness': 0.0606,
#   'valence': 0.0919,
#   'tempo': 72.992,
#   'time_signature': 4},
#  '7qVfJ6wvbtxjtqMrWbvcOo': {'danceability': 0.345,
#   'energy': 0.118,
#   'key': 7,
#   'loudness': -13.44,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.938,
#   'instrumentalness': 0.000107,
#   'liveness': 0.115,
#   'valence': 0.123,
#   'tempo': 145.837,
#   'time_signature': 3},
#  '0ytCr0BRergKfjMYayYycg': {'danceability': 0.32,
#   'energy': 0.801,
#   'key': 0,
#   'loudness': -4.25,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.0354,
#   'instrumentalness': 2.48e-06,
#   'liveness': 0.13,
#   'valence': 0.0991,
#   'tempo': 194.784,
#   'time_signature': 4},
#  '5f8Cn4lVRMUL9sA8oYw3lu': {'danceability': 0.672,
#   'energy': 0.422,
#   'key': 9,
#   'loudness': -10.23,
#   'mode': 0,
#   'speechiness': 0.0296,
#   'acousticness': 0.129,
#   'instrumentalness': 0.0039,
#   'liveness': 0.108,
#   'valence': 0.0981,
#   'tempo': 97.038,
#   'time_signature': 4},
#  '4XfaG7qBZ8qeyrTQ25uXJj': {'danceability': 0.511,
#   'energy': 0.188,
#   'key': 7,
#   'loudness': -10.588,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.875,
#   'instrumentalness': 0.000589,
#   'liveness': 0.137,
#   'valence': 0.232,
#   'tempo': 78.733,
#   'time_signature': 4},
#  '5Z2TvUNflVYGsoFGkvAKzE': {'danceability': 0.327,
#   'energy': 0.269,
#   'key': 4,
#   'loudness': -12.912,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.825,
#   'instrumentalness': 0.000234,
#   'liveness': 0.108,
#   'valence': 0.0857,
#   'tempo': 141.514,
#   'time_signature': 4},
#  '4T8FoNHY3UZSYgOV76ueVU': {'danceability': 0.435,
#   'energy': 0.208,
#   'key': 1,
#   'loudness': -15.75,
#   'mode': 0,
#   'speechiness': 0.0558,
#   'acousticness': 0.647,
#   'instrumentalness': 0.000921,
#   'liveness': 0.147,
#   'valence': 0.189,
#   'tempo': 69.027,
#   'time_signature': 4},
#  '0Kt5AHOpQAkEsHAuPeB0le': {'danceability': 0.525,
#   'energy': 0.461,
#   'key': 5,
#   'loudness': -9.489,
#   'mode': 0,
#   'speechiness': 0.0878,
#   'acousticness': 0.775,
#   'instrumentalness': 2.14e-06,
#   'liveness': 0.362,
#   'valence': 0.202,
#   'tempo': 147.997,
#   'time_signature': 4},
#  '2ZuiQ9Kn9O6v2hWs7cBBQ4': {'danceability': 0.483,
#   'energy': 0.134,
#   'key': 0,
#   'loudness': -12.968,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.982,
#   'instrumentalness': 0.0377,
#   'liveness': 0.149,
#   'valence': 0.224,
#   'tempo': 96.321,
#   'time_signature': 3},
#  '56oReVXIfUO9xkX7pHmEU0': {'danceability': 0.065,
#   'energy': 0.341,
#   'key': 10,
#   'loudness': -12.743,
#   'mode': 0,
#   'speechiness': 0.0482,
#   'acousticness': 0.154,
#   'instrumentalness': 0.854,
#   'liveness': 0.109,
#   'valence': 0.0334,
#   'tempo': 65.38,
#   'time_signature': 4},
#  '0XEUKN8CnHAKNmWmK1FG0d': {'danceability': 0.588,
#   'energy': 0.841,
#   'key': 2,
#   'loudness': -4.374,
#   'mode': 1,
#   'speechiness': 0.0802,
#   'acousticness': 0.144,
#   'instrumentalness': 0.000511,
#   'liveness': 0.0369,
#   'valence': 0.682,
#   'tempo': 92.992,
#   'time_signature': 4},
#  '4WrwO9Un3ji5wnNySDGHwQ': {'danceability': 0.589,
#   'energy': 0.641,
#   'key': 8,
#   'loudness': -5.533,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.427,
#   'instrumentalness': 0,
#   'liveness': 0.0558,
#   'valence': 0.795,
#   'tempo': 204.003,
#   'time_signature': 4},
#  '48mhRAnKkpLVuMmqTMPBUe': {'danceability': 0.501,
#   'energy': 0.643,
#   'key': 1,
#   'loudness': -7.345,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'acousticness': 0.251,
#   'instrumentalness': 0.0267,
#   'liveness': 0.101,
#   'valence': 0.141,
#   'tempo': 139.902,
#   'time_signature': 4},
#  '28nC2aXXUqvQCT3XeJs5Yd': {'danceability': 0.428,
#   'energy': 0.82,
#   'key': 5,
#   'loudness': -5.504,
#   'mode': 0,
#   'speechiness': 0.0803,
#   'acousticness': 0.32,
#   'instrumentalness': 0,
#   'liveness': 0.379,
#   'valence': 0.269,
#   'tempo': 143.366,
#   'time_signature': 4},
#  ...}

# %%
track_features_df = pd.DataFrame.from_dict(track_features, orient='index')
track_features_df.to_csv('datasets/tracks_features_df.csv', index=False)
